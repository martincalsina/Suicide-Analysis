# %% [markdown]
# # Data Cleaning

# %% [markdown]
# In this notebook you will find the used pipeline to clean the datasets that are at our disposition, such as treating missing values, removing inconsistent data and transform all this datasets into ones that follow a number of normalization principles that manage them to be easier to manipulate in the Analysis Notebook.

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd

# %%
# in case of using colab
from google.colab import drive
drive.mount('/content/drive')

current_directory = "/content/drive/MyDrive/Proyectos/Suicidios_Análisis/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## General view of the datasets

# %% [markdown]
# ### Loading the Data

# %% [markdown]
# Suicides registered since 2017.

# %%
df_suicides = pd.read_csv(current_directory+"Data/SAT-SS-BU_2017-2022.csv", sep=",")

# %%
df_suicides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21719 entries, 0 to 21718
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_hecho                     21719 non-null  int64
#  1   federal                      21719 non-null  object
#  2   provincia_id                 21719 non-null  int64
#  3   provincia_nombre             21719 non-null  object
#  4   departamento_id              21719 non-null  int64
#  5   departamento_nombre          21719 non-null  object
#  6   localidad_id                 21719 non-null  object
#  7   localidad_nombre             21719 non-null  object
#  8   anio                         21719 non-null  int64
#  9   mes                          21719 non-null  int64
#  10  fecha_hecho                  21719 non-null  object
#  11  hora_hecho                   21719 non-null  object
#  12  tipo_lugar                   21719 non-null  object
#  13  tipo_lugar_ampliado          21719 non-null  object
#  14  tipo_lugar_otro              1273 non-null   object
#  15  modalidad                    21719 non-null  object
#  16  modalidad_ampliado           21719 non-null  object
#  17  modalidad_otro               225 non-null    object
#  18  motivo_origen_registro       21719 non-null  object
#  19  motivo_origen_registro_otro  14 non-null     object
#  20  suicida_sexo                 21719 non-null  object
#  21  suicida_tr_edad              21719 non-null  object
#  22  suicida_identidad_genero     21719 non-null  object
# dtypes: int64(5), object(18)
# memory usage: 3.8+ MB

# %%
df_suicides.head()
# Out:
#    id_hecho federal  provincia_id provincia_nombre  departamento_id  \
# 0      8529      No            42         La Pampa            42002
# 1      8530      No            42         La Pampa            42003
# 2      8569      No            78       Santa Cruz            78021
# 3      8705      No            58          Neuquén            58035
# 4      8706      No            58          Neuquén            58035
#
#     departamento_nombre localidad_id localidad_nombre  anio  mes  ...  \
# 0  Norte (General Pico)       105030     General Pico  2017    1  ...
# 1    Sur (General Acha)        70030        Guatraché  2017    1  ...
# 2             Güer Aike           60  28 de Noviembre  2017    1  ...
# 3           Confluencia           70          Neuquén  2017    1  ...
# 4           Confluencia          100         Plottier  2017    1  ...
#
#                 tipo_lugar_ampliado                   tipo_lugar_otro  \
# 0                       Vía pública                               NaN
# 1              Domicilio particular                               NaN
# 2                       Vía pública                               NaN
# 3  Hotel/Motel/Hospedaje temporario  Hotel/Motel/Hospedaje temporario
# 4              Domicilio particular                               NaN
#
#        modalidad modalidad_ampliado modalidad_otro motivo_origen_registro  \
# 0   Ahorcamiento       Ahorcamiento            NaN  Intervención policial
# 1  Arma de fuego      Arma de fuego            NaN  Intervención policial
# 2   Ahorcamiento       Ahorcamiento            NaN    Denuncia particular
# 3  Arma de fuego      Arma de fuego            NaN  Intervención policial
# 4   Ahorcamiento       Ahorcamiento            NaN  Intervención policial
#
#   motivo_origen_registro_otro suicida_sexo suicida_tr_edad  \
# 0                         NaN    Masculino           20-24
# 1                         NaN    Masculino           55-59
# 2                         NaN    Masculino           15-19
# 3                         NaN    Masculino           20-24
# 4                         NaN    Masculino           20-24
#
#   suicida_identidad_genero
# 0           Sin determinar
# 1           Sin determinar
# 2           Sin determinar
# 3           Sin determinar
# 4           Sin determinar
#
# [5 rows x 23 columns]

# %%
df_suicides["suicida_identidad_genero"].value_counts()
# Out:
# Sin determinar          14890
# Varón                    5309
# Mujer                    1515
# Mujer trans/travesti        4
# Varón trans                 1
# Name: suicida_identidad_genero, dtype: int64

# %%
df_suicides["modalidad_ampliado"].value_counts()
# Out:
# Ahorcamiento                                          14651
# Arma de fuego                                          3454
# Sin determinar                                         1381
# Se arroja al vacío                                      755
# Envenenamiento                                          576
# Se arroja a las vías de FF.CC.                          279
# Arma blanca /  elemento cortante                        265
# Sumersión en piscina / mar / río                        171
# Se incinera                                             133
# Se arroja bajo rodado (camion/automóvil/colectivo)       36
# Otra modalidad                                           18
# Name: modalidad_ampliado, dtype: int64

# %% [markdown]
# Crime statistics since 2000.

# %%
# this one uses ";" even if it is called ".csv"
df_crimes = pd.read_csv(current_directory+"Data/snic-provincias.csv", sep=";", error_bad_lines=False)
# Out:
# <ipython-input-8-867ebba2552b>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_crimes = pd.read_csv(current_directory+"Data/snic-provincias.csv", sep=";", error_bad_lines=False)

# %%
df_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21344 entries, 0 to 21343
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   provincia_id               21344 non-null  int64
#  1   provincia_nombre           21344 non-null  object
#  2   anio                       21344 non-null  int64
#  3   codigo_delito_snic_id      21344 non-null  object
#  4   codigo_delito_snic_nombre  21344 non-null  object
#  5   cantidad_hechos            21344 non-null  int64
#  6   cantidad_victimas          7608 non-null   float64
#  7   cantidad_victimas_masc     7608 non-null   float64
#  8   cantidad_victimas_fem      7608 non-null   float64
#  9   cantidad_victimas_sd       7608 non-null   float64
#  10  tasa_hechos                21344 non-null  object
#  11  tasa_victimas              7608 non-null   object
#  12  tasa_victimas_masc         7608 non-null   object
#  13  tasa_victimas_fem          7608 non-null   object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 2.3+ MB

# %%
df_crimes.head()
# Out:
#    provincia_id                 provincia_nombre  anio codigo_delito_snic_id  \
# 0             2  Ciudad Autónoma de Buenos Aires  2000                     1
# 1             2  Ciudad Autónoma de Buenos Aires  2000                     2
# 2             2  Ciudad Autónoma de Buenos Aires  2000                     3
# 3             2  Ciudad Autónoma de Buenos Aires  2000                     4
# 4             2  Ciudad Autónoma de Buenos Aires  2000                     5
#
#                   codigo_delito_snic_nombre  cantidad_hechos  \
# 0                        Homicidios dolosos              149
# 1  Homicidios dolosos en grado de tentativa               54
# 2              Muertes en accidentes viales              121
# 3      Homicidios culposos por otros hechos               35
# 4                          Lesiones dolosas            13154
#
#    cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 0              158.0                   121.0                   37.0
# 1               58.0                    40.0                   18.0
# 2              126.0                    97.0                   29.0
# 3               36.0                    20.0                   13.0
# 4            13732.0                  8105.0                 5485.0
#
#    cantidad_victimas_sd tasa_hechos tasa_victimas tasa_victimas_masc  \
# 0                   0.0   4,9750013     5,2755051          8,8257008
# 1                   0.0   1,8030207     1,9365778          2,9175868
# 2                   0.0    4,040102     4,2070484          7,0751481
# 3                   3.0   1,1686245     1,2020137          1,4587934
# 4                 142.0   439,20248     458,50146          591,17603
#
#   tasa_victimas_fem
# 0         2,2783601
# 1         1,1083914
# 2         1,7857418
# 3         ,80050492
# 4          337,7515

# %% [markdown]
# Wage Mean Income by Department and CLAE2 since 2014.

# %%
df_mean_income = pd.read_csv(current_directory+"Data/w_mean_depto_tot_emp_clae2.csv", sep=",")

# %%
df_mean_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3597481 entries, 0 to 3597480
# Data columns (total 5 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   fecha                      object
#  1   codigo_departamento_indec  float64
#  2   id_provincia_indec         float64
#  3   clae2                      int64
#  4   w_mean                     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 137.2+ MB

# %%
df_mean_income.head(10)
# Out:
#         fecha  codigo_departamento_indec  id_provincia_indec  clae2  w_mean
# 0  2014-01-01                     2000.0                 2.0      1   13085
# 1  2014-01-01                     2000.0                 2.0      2   10081
# 2  2014-01-01                     2000.0                 2.0      3   17837
# 3  2014-01-01                     2000.0                 2.0      5   57688
# 4  2014-01-01                     2000.0                 2.0      6   62211
# 5  2014-01-01                     2000.0                 2.0      7   50522
# 6  2014-01-01                     2000.0                 2.0      8   50411
# 7  2014-01-01                     2000.0                 2.0      9   41279
# 8  2014-01-01                     2000.0                 2.0     10   16659
# 9  2014-01-01                     2000.0                 2.0     11   23518

# %%
df_mean_income["fecha"].unique()
# Out:
# array(['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#        '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#        '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#        '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#        '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#        '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#        '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#        '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#        '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#        '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#        '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#        '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#        '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#        '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#        '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#        '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#        '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#        '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#        '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
#        '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
#        '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#        '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#        '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#        '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#        '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#        '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#        '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#        '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#        '2023-09-01'], dtype=object)

# %% [markdown]
# Provinces and Departments of Argentina by INDEC's standard.

# %%
df_locations = pd.read_csv(current_directory+"Data/diccionario_cod_depto.csv", sep=",")

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   codigo_departamento_indec  510 non-null    int64
#  1   nombre_departamento_indec  510 non-null    object
#  2   id_provincia_indec         510 non-null    int64
#  3   nombre_provincia_indec     510 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 16.1+ KB

# %%
df_locations.head()
# Out:
#    codigo_departamento_indec nombre_departamento_indec  id_provincia_indec  \
# 0                       2000                      CABA                   2
# 1                       6007             Adolfo Alsina                   6
# 2                       6014    Adolfo Gonzales Chaves                   6
# 3                       6021                   Alberti                   6
# 4                       6028           Almirante Brown                   6
#
#   nombre_provincia_indec
# 0                   CABA
# 1           Buenos Aires
# 2           Buenos Aires
# 3           Buenos Aires
# 4           Buenos Aires

# %% [markdown]
# CLAE2 dictionary

# %%
df_clae2 = pd.read_csv(current_directory+"Data/diccionario_clae2.csv", sep=",")

# %%
df_clae2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   clae2       86 non-null     int64
#  1   clae2_desc  86 non-null     object
#  2   letra       85 non-null     object
#  3   letra_desc  86 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.8+ KB

# %%
df_clae2.head()
# Out:
#    clae2                                         clae2_desc letra  \
# 0      1  Agricultura, ganadería, caza y servicios relac...     A
# 1      2                Silvicultura y explotación forestal     A
# 2      3                                Pesca y acuicultura     A
# 3      5                     Extracción de carbón y lignito     B
# 4      6         Extracción de petróleo crudo y gas natural     B
#
#                                           letra_desc
# 0   AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y ...
# 1   AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y ...
# 2   AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y ...
# 3                    EXPLOTACION DE MINAS Y CANTERAS
# 4                    EXPLOTACION DE MINAS Y CANTERAS

# %% [markdown]
# ### Strategy

# %% [markdown]
# We will create the corresponding datasets that map the Relational Model that follows this ERD (Entity Relation Diagram):
#
# ![Suicide Analysis ERD](https://drive.google.com/uc?id=1islpEu6Dd5pdxKj9CztsnAgzJIQvN42F)

# %% [markdown]
# We will not preserve all the columns for each dataset. The most important will remain, the ones that are shared with other tables (like the province or the department) will form part of other table and the ones that we not consider significant will be dropped out.

# %% [markdown]
# Once that is done, we will get deeper into each of the generated tables so we make sure that the data is consistent and useful for our purpose.

# %% [markdown]
# Then, we can finally start with the Analysis part.

# %% [markdown]
# ## Mapping to the relational model

# %% [markdown]
# ### INDEC Locations

# %% [markdown]
# We have two independent entites: the provinces (PROVINCIA) and the CLAEs (CLAE2). With the INDEC locations dataset we will be able to get the provinces and, also, the departments that are related to them.

# %%
df_locations
# Out:
#      codigo_departamento_indec nombre_departamento_indec  id_provincia_indec  \
# 0                         2000                      CABA                   2
# 1                         6007             Adolfo Alsina                   6
# 2                         6014    Adolfo Gonzales Chaves                   6
# 3                         6021                   Alberti                   6
# 4                         6028           Almirante Brown                   6
# ..                         ...                       ...                 ...
# 505                      90105                Tafí Viejo                  90
# 506                      90112                   Trancas                  90
# 507                      90119               Yerba Buena                  90
# 508                      94007        Río Grande/Tolhuin                  94
# 509                      94014                   Ushuaia                  94
#
#     nombre_provincia_indec
# 0                     CABA
# 1             Buenos Aires
# 2             Buenos Aires
# 3             Buenos Aires
# 4             Buenos Aires
# ..                     ...
# 505                Tucuman
# 506                Tucuman
# 507                Tucuman
# 508       Tierra Del Fuego
# 509       Tierra Del Fuego
#
# [510 rows x 4 columns]

# %%
provinces = df_locations[["id_provincia_indec", "nombre_provincia_indec"]].copy()

# %%
provinces.drop_duplicates(inplace=True)

# %%
provinces.reset_index(inplace=True)

# %%
provinces.drop(axis=1, labels=["index"], inplace=True)

# %%
provinces
# Out:
#     id_provincia_indec nombre_provincia_indec
# 0                    2                   CABA
# 1                    6           Buenos Aires
# 2                   10              Catamarca
# 3                   14                Cordoba
# 4                   18             Corrientes
# 5                   22                  Chaco
# 6                   26                 Chubut
# 7                   30             Entre Rios
# 8                   34                Formosa
# 9                   38                  Jujuy
# 10                  42               La Pampa
# 11                  46               La Rioja
# 12                  50                Mendoza
# 13                  54               Misiones
# 14                  58                Neuquen
# 15                  62              Rio Negro
# 16                  66                  Salta
# 17                  70               San Juan
# 18                  74               San Luis
# 19                  78             Santa Cruz
# 20                  82               Santa Fe
# 21                  86    Santiago Del Estero
# 22                  90                Tucuman
# 23                  94       Tierra Del Fuego

# %% [markdown]
# We go the 24 provinces (counting CABA) from Argentina with their INDEC ids and names.

# %%
provinces.columns = [["id_indec", "nombre_indec"]]

# %%
provinces
# Out:
#    id_indec         nombre_indec
# 0         2                 CABA
# 1         6         Buenos Aires
# 2        10            Catamarca
# 3        14              Cordoba
# 4        18           Corrientes
# 5        22                Chaco
# 6        26               Chubut
# 7        30           Entre Rios
# 8        34              Formosa
# 9        38                Jujuy
# 10       42             La Pampa
# 11       46             La Rioja
# 12       50              Mendoza
# 13       54             Misiones
# 14       58              Neuquen
# 15       62            Rio Negro
# 16       66                Salta
# 17       70             San Juan
# 18       74             San Luis
# 19       78           Santa Cruz
# 20       82             Santa Fe
# 21       86  Santiago Del Estero
# 22       90              Tucuman
# 23       94     Tierra Del Fuego

# %% [markdown]
# Now we can proceed with the departments

# %%
departments = df_locations[["codigo_departamento_indec", "nombre_departamento_indec", "id_provincia_indec"]].copy()

# %%
departments.drop_duplicates(inplace=True)

# %%
departments.reset_index(inplace=True)

# %%
departments.drop(axis=1, labels=["index"], inplace=True)

# %%
departments
# Out:
#      codigo_departamento_indec nombre_departamento_indec  id_provincia_indec
# 0                         2000                      CABA                   2
# 1                         6007             Adolfo Alsina                   6
# 2                         6014    Adolfo Gonzales Chaves                   6
# 3                         6021                   Alberti                   6
# 4                         6028           Almirante Brown                   6
# ..                         ...                       ...                 ...
# 505                      90105                Tafí Viejo                  90
# 506                      90112                   Trancas                  90
# 507                      90119               Yerba Buena                  90
# 508                      94007        Río Grande/Tolhuin                  94
# 509                      94014                   Ushuaia                  94
#
# [510 rows x 3 columns]

# %%
departments.columns = ["id_indec", "nombre_indec", "id_provincia_indec"]

# %%
departments
# Out:
#      id_indec            nombre_indec  id_provincia_indec
# 0        2000                    CABA                   2
# 1        6007           Adolfo Alsina                   6
# 2        6014  Adolfo Gonzales Chaves                   6
# 3        6021                 Alberti                   6
# 4        6028         Almirante Brown                   6
# ..        ...                     ...                 ...
# 505     90105              Tafí Viejo                  90
# 506     90112                 Trancas                  90
# 507     90119             Yerba Buena                  90
# 508     94007      Río Grande/Tolhuin                  94
# 509     94014                 Ushuaia                  94
#
# [510 rows x 3 columns]

# %% [markdown]
# This should be enough for this dataset by now.
#
# Since there is a relation 1 to N between the provinces and the departments, these last ones will retain their corresponding province id.

# %%
del df_locations

# %% [markdown]
# ### Crimes

# %% [markdown]
# From this one we will get the DELITO entity model. Most of the columns will remain, we only have to make sure that their province id corresponds with the INDEC's one.

# %%
df_crimes
# Out:
#        provincia_id                                   provincia_nombre  anio  \
# 0                 2                    Ciudad Autónoma de Buenos Aires  2000
# 1                 2                    Ciudad Autónoma de Buenos Aires  2000
# 2                 2                    Ciudad Autónoma de Buenos Aires  2000
# 3                 2                    Ciudad Autónoma de Buenos Aires  2000
# 4                 2                    Ciudad Autónoma de Buenos Aires  2000
# ...             ...                                                ...   ...
# 21339            94  Tierra del Fuego, Antártida e Islas del Atlánt...  2022
# 21340            94  Tierra del Fuego, Antártida e Islas del Atlánt...  2022
# 21341            94  Tierra del Fuego, Antártida e Islas del Atlánt...  2022
# 21342            94  Tierra del Fuego, Antártida e Islas del Atlánt...  2022
# 21343            94  Tierra del Fuego, Antártida e Islas del Atlánt...  2022
#
#       codigo_delito_snic_id  \
# 0                         1
# 1                         2
# 2                         3
# 3                         4
# 4                         5
# ...                     ...
# 21339                  29_7
# 21340                  29_8
# 21341                    30
# 21342                    31
# 21343                    32
#
#                                codigo_delito_snic_nombre  cantidad_hechos  \
# 0                                     Homicidios dolosos              149
# 1               Homicidios dolosos en grado de tentativa               54
# 2                           Muertes en accidentes viales              121
# 3                   Homicidios culposos por otros hechos               35
# 4                                       Lesiones dolosas            13154
# ...                                                  ...              ...
# 21339  Contrabando de elementos nucleares agresivos q...                0
# 21340  Otros delitos previstos en leyes especiales n,c,p             3082
# 21341                                    Contravenciones              557
# 21342                             Suicidios (consumados)               22
# 21343     Delitos contra el orden económico y financiero                2
#
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 0                  158.0                   121.0                   37.0
# 1                   58.0                    40.0                   18.0
# 2                  126.0                    97.0                   29.0
# 3                   36.0                    20.0                   13.0
# 4                13732.0                  8105.0                 5485.0
# ...                  ...                     ...                    ...
# 21339                NaN                     NaN                    NaN
# 21340                NaN                     NaN                    NaN
# 21341                NaN                     NaN                    NaN
# 21342               22.0                    12.0                   10.0
# 21343                NaN                     NaN                    NaN
#
#        cantidad_victimas_sd tasa_hechos tasa_victimas tasa_victimas_masc  \
# 0                       0.0   4,9750013     5,2755051          8,8257008
# 1                       0.0   1,8030207     1,9365778          2,9175868
# 2                       0.0    4,040102     4,2070484          7,0751481
# 3                       3.0   1,1686245     1,2020137          1,4587934
# 4                     142.0   439,20248     458,50146          591,17603
# ...                     ...         ...           ...                ...
# 21339                   NaN           0           NaN                NaN
# 21340                   NaN   1693,5648           NaN                NaN
# 21341                   NaN   306,07254           NaN                NaN
# 21342                   0.0   13,150816     13,150816          14,091123
# 21343                   NaN   1,0990038           NaN                NaN
#
#       tasa_victimas_fem
# 0             2,2783601
# 1             1,1083914
# 2             1,7857418
# 3             ,80050492
# 4              337,7515
# ...                 ...
# 21339               NaN
# 21340               NaN
# 21341               NaN
# 21342         12,175818
# 21343               NaN
#
# [21344 rows x 14 columns]

# %%
crimes_provinces = df_crimes[["provincia_id", "provincia_nombre"]].copy()

# %%
crimes_provinces.drop_duplicates(inplace=True)

# %%
crimes_provinces
# Out:
#        provincia_id                                   provincia_nombre
# 0                 2                    Ciudad Autónoma de Buenos Aires
# 888               6                                       Buenos Aires
# 1776             10                                          Catamarca
# 2664             14                                            Córdoba
# 3552             18                                         Corrientes
# 4440             22                                              Chaco
# 5336             26                                             Chubut
# 6224             30                                         Entre Ríos
# 7112             34                                            Formosa
# 8000             38                                              Jujuy
# 8888             42                                           La Pampa
# 9784             46                                           La Rioja
# 10672            50                                            Mendoza
# 11560            54                                           Misiones
# 12448            58                                            Neuquén
# 13336            62                                          Río Negro
# 14224            66                                              Salta
# 15120            70                                           San Juan
# 16008            74                                           San Luis
# 16896            78                                         Santa Cruz
# 17784            82                                           Santa Fe
# 18672            86                                Santiago del Estero
# 19568            90                                            Tucumán
# 20456            94  Tierra del Fuego, Antártida e Islas del Atlánt...

# %% [markdown]
# Our INDEC table was

# %%
provinces
# Out:
#    id_indec         nombre_indec
# 0         2                 CABA
# 1         6         Buenos Aires
# 2        10            Catamarca
# 3        14              Cordoba
# 4        18           Corrientes
# 5        22                Chaco
# 6        26               Chubut
# 7        30           Entre Rios
# 8        34              Formosa
# 9        38                Jujuy
# 10       42             La Pampa
# 11       46             La Rioja
# 12       50              Mendoza
# 13       54             Misiones
# 14       58              Neuquen
# 15       62            Rio Negro
# 16       66                Salta
# 17       70             San Juan
# 18       74             San Luis
# 19       78           Santa Cruz
# 20       82             Santa Fe
# 21       86  Santiago Del Estero
# 22       90              Tucuman
# 23       94     Tierra Del Fuego

# %% [markdown]
# The ids are the correct, but some of the names are different, they are not abbreviated or they use some special characters.
#
# Since there is a relation 1 to N between PROVINCIA and  DELITO, this table only needs to know the id of their province, using a join it will be able to recover the correct name.
#
# So on, we only need to filter the columns that we will use and rename them conveniently.

# %%
del crimes_provinces

# %%
df_crimes.columns
# Out:
# Index(['provincia_id', 'provincia_nombre', 'anio', 'codigo_delito_snic_id',
#        'codigo_delito_snic_nombre', 'cantidad_hechos', 'cantidad_victimas',
#        'cantidad_victimas_masc', 'cantidad_victimas_fem',
#        'cantidad_victimas_sd', 'tasa_hechos', 'tasa_victimas',
#        'tasa_victimas_masc', 'tasa_victimas_fem'],
#       dtype='object')

# %%
df_crimes.drop(axis=1, labels=['provincia_nombre'], inplace=True)

# %%
df_crimes.columns
# Out:
# Index(['provincia_id', 'anio', 'codigo_delito_snic_id',
#        'codigo_delito_snic_nombre', 'cantidad_hechos', 'cantidad_victimas',
#        'cantidad_victimas_masc', 'cantidad_victimas_fem',
#        'cantidad_victimas_sd', 'tasa_hechos', 'tasa_victimas',
#        'tasa_victimas_masc', 'tasa_victimas_fem'],
#       dtype='object')

# %%
new_names = ["id_provincia_indec", "anio", "id_snic", "nombre_snic", 'cantidad_hechos', 'cantidad_victimas',
       'cantidad_victimas_masc', 'cantidad_victimas_fem',
       'cantidad_victimas_sd', 'tasa_hechos', 'tasa_victimas',
       'tasa_victimas_masc', 'tasa_victimas_fem']

df_crimes.columns = new_names

# %%
df_crimes
# Out:
#        id_provincia_indec  anio id_snic  \
# 0                       2  2000       1
# 1                       2  2000       2
# 2                       2  2000       3
# 3                       2  2000       4
# 4                       2  2000       5
# ...                   ...   ...     ...
# 21339                  94  2022    29_7
# 21340                  94  2022    29_8
# 21341                  94  2022      30
# 21342                  94  2022      31
# 21343                  94  2022      32
#
#                                              nombre_snic  cantidad_hechos  \
# 0                                     Homicidios dolosos              149
# 1               Homicidios dolosos en grado de tentativa               54
# 2                           Muertes en accidentes viales              121
# 3                   Homicidios culposos por otros hechos               35
# 4                                       Lesiones dolosas            13154
# ...                                                  ...              ...
# 21339  Contrabando de elementos nucleares agresivos q...                0
# 21340  Otros delitos previstos en leyes especiales n,c,p             3082
# 21341                                    Contravenciones              557
# 21342                             Suicidios (consumados)               22
# 21343     Delitos contra el orden económico y financiero                2
#
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 0                  158.0                   121.0                   37.0
# 1                   58.0                    40.0                   18.0
# 2                  126.0                    97.0                   29.0
# 3                   36.0                    20.0                   13.0
# 4                13732.0                  8105.0                 5485.0
# ...                  ...                     ...                    ...
# 21339                NaN                     NaN                    NaN
# 21340                NaN                     NaN                    NaN
# 21341                NaN                     NaN                    NaN
# 21342               22.0                    12.0                   10.0
# 21343                NaN                     NaN                    NaN
#
#        cantidad_victimas_sd tasa_hechos tasa_victimas tasa_victimas_masc  \
# 0                       0.0   4,9750013     5,2755051          8,8257008
# 1                       0.0   1,8030207     1,9365778          2,9175868
# 2                       0.0    4,040102     4,2070484          7,0751481
# 3                       3.0   1,1686245     1,2020137          1,4587934
# 4                     142.0   439,20248     458,50146          591,17603
# ...                     ...         ...           ...                ...
# 21339                   NaN           0           NaN                NaN
# 21340                   NaN   1693,5648           NaN                NaN
# 21341                   NaN   306,07254           NaN                NaN
# 21342                   0.0   13,150816     13,150816          14,091123
# 21343                   NaN   1,0990038           NaN                NaN
#
#       tasa_victimas_fem
# 0             2,2783601
# 1             1,1083914
# 2             1,7857418
# 3             ,80050492
# 4              337,7515
# ...                 ...
# 21339               NaN
# 21340               NaN
# 21341               NaN
# 21342         12,175818
# 21343               NaN
#
# [21344 rows x 13 columns]

# %%
crimes = df_crimes.copy()

# %%
del df_crimes

# %% [markdown]
# ### Suicides

# %% [markdown]
# With this one we will need to drop some columns and rename others. Also, we will need to make sure that the departments ids are the INDEC ones.

# %%
df_suicides
# Out:
#        id_hecho federal  provincia_id provincia_nombre  departamento_id  \
# 0          8529      No            42         La Pampa            42002
# 1          8530      No            42         La Pampa            42003
# 2          8569      No            78       Santa Cruz            78021
# 3          8705      No            58          Neuquén            58035
# 4          8706      No            58          Neuquén            58035
# ...         ...     ...           ...              ...              ...
# 21714     37640      No            18       Corrientes            18049
# 21715     37642      No            18       Corrientes            18070
# 21716     37643      No            18       Corrientes            18070
# 21717     37639      No            18       Corrientes            18133
# 21718     32650      No            42         La Pampa            42001
#
#         departamento_nombre localidad_id localidad_nombre  anio  mes  ...  \
# 0      Norte (General Pico)       105030     General Pico  2017    1  ...
# 1        Sur (General Acha)        70030        Guatraché  2017    1  ...
# 2                 Güer Aike           60  28 de Noviembre  2017    1  ...
# 3               Confluencia           70          Neuquén  2017    1  ...
# 4               Confluencia          100         Plottier  2017    1  ...
# ...                     ...          ...              ...   ...  ...  ...
# 21714               Esquina           10          Esquina  2022    7  ...
# 21715                  Goya           20             Goya  2022    9  ...
# 21716                  Goya           20             Goya  2022    9  ...
# 21717             San Cosme           30        San Cosme  2022    7  ...
# 21718   Centro (Santa Rosa)        21020       Santa Rosa  2022    3  ...
#
#                     tipo_lugar_ampliado                   tipo_lugar_otro  \
# 0                           Vía pública                               NaN
# 1                  Domicilio particular                               NaN
# 2                           Vía pública                               NaN
# 3      Hotel/Motel/Hospedaje temporario  Hotel/Motel/Hospedaje temporario
# 4                  Domicilio particular                               NaN
# ...                                 ...                               ...
# 21714                Cárcel o comisaría                               NaN
# 21715              Domicilio particular                               NaN
# 21716              Domicilio particular                               NaN
# 21717       Campo/descampado/zona rural       Campo/descampado/zona rural
# 21718              Domicilio particular                               NaN
#
#             modalidad modalidad_ampliado modalidad_otro  \
# 0        Ahorcamiento       Ahorcamiento            NaN
# 1       Arma de fuego      Arma de fuego            NaN
# 2        Ahorcamiento       Ahorcamiento            NaN
# 3       Arma de fuego      Arma de fuego            NaN
# 4        Ahorcamiento       Ahorcamiento            NaN
# ...               ...                ...            ...
# 21714    Ahorcamiento       Ahorcamiento            NaN
# 21715  Sin determinar     Sin determinar            NaN
# 21716    Ahorcamiento       Ahorcamiento            NaN
# 21717    Ahorcamiento       Ahorcamiento            NaN
# 21718   Arma de fuego      Arma de fuego            NaN
#
#       motivo_origen_registro motivo_origen_registro_otro suicida_sexo  \
# 0      Intervención policial                         NaN    Masculino
# 1      Intervención policial                         NaN    Masculino
# 2        Denuncia particular                         NaN    Masculino
# 3      Intervención policial                         NaN    Masculino
# 4      Intervención policial                         NaN    Masculino
# ...                      ...                         ...          ...
# 21714  Intervención policial                         NaN    Masculino
# 21715  Intervención policial                         NaN    Masculino
# 21716  Intervención policial                         NaN    Masculino
# 21717  Intervención policial                         NaN    Masculino
# 21718    Denuncia particular                         NaN    Masculino
#
#       suicida_tr_edad suicida_identidad_genero
# 0               20-24           Sin determinar
# 1               55-59           Sin determinar
# 2               15-19           Sin determinar
# 3               20-24           Sin determinar
# 4               20-24           Sin determinar
# ...               ...                      ...
# 21714           30-34                    Varón
# 21715           50-54                    Varón
# 21716           15-19                    Varón
# 21717           30-34                    Varón
# 21718           40-44                    Varón
#
# [21719 rows x 23 columns]

# %%
suicides_departments = df_suicides[["departamento_id", "departamento_nombre"]].copy()

# %%
suicides_departments.drop_duplicates(inplace=True)

# %%
suicides_departments
# Out:
#        departamento_id          departamento_nombre
# 0                42002         Norte (General Pico)
# 1                42003           Sur (General Acha)
# 2                78021                    Güer Aike
# 3                58035                  Confluencia
# 6                58049                    Huiliches
# ...                ...                          ...
# 18600            10056                      El Alto
# 18800            38098                      Tumbaya
# 19327            10028     Antofagasta de la Sierra
# 19422            58999  Departamento sin determinar
# 21364            14154                   Sobremonte
#
# [505 rows x 2 columns]

# %%
departments #the indec based ones
# Out:
#      id_indec            nombre_indec  id_provincia_indec
# 0        2000                    CABA                   2
# 1        6007           Adolfo Alsina                   6
# 2        6014  Adolfo Gonzales Chaves                   6
# 3        6021                 Alberti                   6
# 4        6028         Almirante Brown                   6
# ..        ...                     ...                 ...
# 505     90105              Tafí Viejo                  90
# 506     90112                 Trancas                  90
# 507     90119             Yerba Buena                  90
# 508     94007      Río Grande/Tolhuin                  94
# 509     94014                 Ushuaia                  94
#
# [510 rows x 3 columns]

# %% [markdown]
# The suicide based ones are 505, while the INDEC's are 510. This can be because there isn´t any register for some of the departments. However, we have to check that the ones that appear are the correct ones.

# %%
suicides_departments.columns = ["id_indec", "nombre_indec"]

# %%
merged_departments = pd.merge(suicides_departments, departments, on="id_indec", how="left")

# %%
merged_departments
# Out:
#      id_indec               nombre_indec_x            nombre_indec_y  \
# 0       42002         Norte (General Pico)                       NaN
# 1       42003           Sur (General Acha)                       NaN
# 2       78021                    Güer Aike                 Güer Aike
# 3       58035                  Confluencia               Confluencia
# 4       58049                    Huiliches                 Huiliches
# ..        ...                          ...                       ...
# 500     10056                      El Alto                   El Alto
# 501     38098                      Tumbaya                   Tumbaya
# 502     10028     Antofagasta de la Sierra  Antofagasta de la Sierra
# 503     58999  Departamento sin determinar                       NaN
# 504     14154                   Sobremonte                Sobremonte
#
#      id_provincia_indec
# 0                   NaN
# 1                   NaN
# 2                  78.0
# 3                  58.0
# 4                  58.0
# ..                  ...
# 500                10.0
# 501                38.0
# 502                10.0
# 503                 NaN
# 504                14.0
#
# [505 rows x 4 columns]

# %% [markdown]
# We merged the tables x (suicides_departments) and y (departments) with this kind of pandas left join.
#
# We can see that some names that are from the suicides table doesn´t correspond to any of the INDEC's registers. Therefore, these one have NaN values in the `y` columns.
#
# How frecuently does this happen?

# %%
incorrect_pairs = merged_departments[merged_departments["nombre_indec_x"] != merged_departments["nombre_indec_y"]]

# %%
incorrect_pairs
# Out:
#      id_indec               nombre_indec_x              nombre_indec_y  \
# 0       42002         Norte (General Pico)                         NaN
# 1       42003           Sur (General Acha)                         NaN
# 8       66056      Grl. José de San Martín  General José de San Martín
# 12      66035                   Cerrillos                    Cerrillos
# 17      58112                      Zapala                       Zapala
# ..        ...                          ...                         ...
# 468     22126                   1º de Mayo                  1° de Mayo
# 478     46056    General Angel V. Peñaloza      Ángel Vicente Peñaloza
# 485     46119       San Blas de los Sauces      San Blas de Los Sauces
# 495     46049                    Famatina                     Famatina
# 503     58999  Departamento sin determinar                         NaN
#
#      id_provincia_indec
# 0                   NaN
# 1                   NaN
# 8                  66.0
# 12                 66.0
# 17                 58.0
# ..                  ...
# 468                22.0
# 478                46.0
# 485                46.0
# 495                46.0
# 503                 NaN
#
# [66 rows x 4 columns]

# %% [markdown]
# We have 66 over 505 rows with problems. However, it seems like some of them, the ones that doesn´t have a `NaN` value in the `y` column, have a pretty correct name, it differs just a little from the original ones.
#
# As these are not really a lot of rows, let´s see this directly

# %%
incorrect_pairs.head(66)
# Out:
#      id_indec               nombre_indec_x              nombre_indec_y  \
# 0       42002         Norte (General Pico)                         NaN
# 1       42003           Sur (General Acha)                         NaN
# 8       66056      Grl. José de San Martín  General José de San Martín
# 12      66035                   Cerrillos                    Cerrillos
# 17      58112                      Zapala                       Zapala
# ..        ...                          ...                         ...
# 468     22126                   1º de Mayo                  1° de Mayo
# 478     46056    General Angel V. Peñaloza      Ángel Vicente Peñaloza
# 485     46119       San Blas de los Sauces      San Blas de Los Sauces
# 495     46049                    Famatina                     Famatina
# 503     58999  Departamento sin determinar                         NaN
#
#      id_provincia_indec
# 0                   NaN
# 1                   NaN
# 8                  66.0
# 12                 66.0
# 17                 58.0
# ..                  ...
# 468                22.0
# 478                46.0
# 485                46.0
# 495                46.0
# 503                 NaN
#
# [66 rows x 4 columns]

# %% [markdown]
# It looks that is the case. The departments that doesn´t have a `NaN` value in the `y` column are valid ones, it just that some of the suicide's table ones have accents, white spices or typos like "Gral." in replacement for "General". We can simply preserve the merged INDEC names in these cases.
#
# Now, what we can do with the `NaN` ones?

# %%
merged_departments["nombre_indec_y"].isna().sum()
# Out:
# 31

# %% [markdown]
# There are 31 of them. However, some are "Departamento sin determinar and other "Comuna N". There is an INDEC id for the non-determinated departments and a "Comuna" one means that it belongs to CABA. Therefore, without this ones, the incorrect pairs would be:

# %%
incorrect_pairs = incorrect_pairs[incorrect_pairs["nombre_indec_y"].isna()]

# %%
incorrect_pairs = incorrect_pairs[incorrect_pairs["nombre_indec_x"] != "Departamento sin determinar"]

# %%
incorrect_pairs = incorrect_pairs[incorrect_pairs.apply(lambda x: not ("Comuna" in x['nombre_indec_x']), axis=1)]

# %%
incorrect_pairs
# Out:
#      id_indec        nombre_indec_x nombre_indec_y  id_provincia_indec
# 0       42002  Norte (General Pico)            NaN                 NaN
# 1       42003    Sur (General Acha)            NaN                 NaN
# 23      66077            La Caldera            NaN                 NaN
# 80      42001   Centro (Santa Rosa)            NaN                 NaN
# 82      42004    Oeste (25 de Mayo)            NaN                 NaN
# 342      6466                Lezama            NaN                 NaN

# %% [markdown]
# So this are really the only problematic departments.
#
# However, it seems like the ones that uses parentesis are just a more specific description of those. For example, we can check that `Santa Rosa` and `25 de Mayo` really exist.
#
# For `La Caldera` and `Lezama` we don´t have insight on what we can do. But as these are just a few rows, we can see if our INDEC tables has the corresponding values.

# %%
searched_departments = ["General Pico", "General Acha", "Santa Rosa", "25 de Mayo"]

departments[departments["nombre_indec"].isin(searched_departments)]
# Out:
#      id_indec nombre_indec  id_provincia_indec
# 130      6854   25 de Mayo                   6
# 148     10098   Santa Rosa                  10
# 226     22168   25 de Mayo                  22
# 339     50112   Santa Rosa                  50
# 358     54119   25 de Mayo                  54
# 387     62091   25 de Mayo                  62
# 427     70126   25 de Mayo                  70

# %% [markdown]
# There are multiple `Santa Rosa` and `25 de Mayo` locations, depending on the province. But our dataset has only one possibility for each, so cases that are from one of these have to share the same province.

# %%
df_suicides[df_suicides["departamento_id"].isin([42001, 42004])]
# Out:
#        id_hecho federal  provincia_id provincia_nombre  departamento_id  \
# 418        9221      No            42         La Pampa            42001
# 419        9222      No            42         La Pampa            42001
# 420        9219      No            42         La Pampa            42001
# 421        9220      No            42         La Pampa            42001
# 428        9229      No            42         La Pampa            42001
# ...         ...     ...           ...              ...              ...
# 19305     34974      No            42         La Pampa            42001
# 19307     34976      No            42         La Pampa            42001
# 19308     34977      No            42         La Pampa            42001
# 19309     34978      No            42         La Pampa            42001
# 21718     32650      No            42         La Pampa            42001
#
#        departamento_nombre localidad_id localidad_nombre  anio  mes  ...  \
# 418    Centro (Santa Rosa)        21020       Santa Rosa  2017    7  ...
# 419    Centro (Santa Rosa)         7030    Miguel Riglos  2017    7  ...
# 420    Centro (Santa Rosa)       140020             Toay  2017    7  ...
# 421    Centro (Santa Rosa)        21020       Santa Rosa  2017    7  ...
# 428    Centro (Santa Rosa)        21020       Santa Rosa  2017    8  ...
# ...                    ...          ...              ...   ...  ...  ...
# 19305  Centro (Santa Rosa)        21020       Santa Rosa  2022   12  ...
# 19307  Centro (Santa Rosa)        21020       Santa Rosa  2022   12  ...
# 19308  Centro (Santa Rosa)        21020       Santa Rosa  2022   12  ...
# 19309  Centro (Santa Rosa)        98050        Victorica  2022   12  ...
# 21718  Centro (Santa Rosa)        21020       Santa Rosa  2022    3  ...
#
#         tipo_lugar_ampliado tipo_lugar_otro       modalidad  \
# 418    Domicilio particular             NaN    Ahorcamiento
# 419    Domicilio particular             NaN   Arma de fuego
# 420    Domicilio particular             NaN    Ahorcamiento
# 421    Domicilio particular             NaN    Ahorcamiento
# 428    Domicilio particular             NaN    Ahorcamiento
# ...                     ...             ...             ...
# 19305  Domicilio particular             NaN    Ahorcamiento
# 19307  Domicilio particular             NaN    Ahorcamiento
# 19308  Domicilio particular             NaN    Ahorcamiento
# 19309  Domicilio particular             NaN  Envenenamiento
# 21718  Domicilio particular             NaN   Arma de fuego
#
#       modalidad_ampliado modalidad_otro motivo_origen_registro  \
# 418         Ahorcamiento            NaN  Intervención policial
# 419        Arma de fuego            NaN  Intervención policial
# 420         Ahorcamiento            NaN  Intervención policial
# 421         Ahorcamiento            NaN  Intervención policial
# 428         Ahorcamiento            NaN  Intervención policial
# ...                  ...            ...                    ...
# 19305       Ahorcamiento            NaN  Intervención policial
# 19307       Ahorcamiento            NaN    Denuncia particular
# 19308       Ahorcamiento            NaN    Denuncia particular
# 19309     Envenenamiento            NaN  Intervención policial
# 21718      Arma de fuego            NaN    Denuncia particular
#
#       motivo_origen_registro_otro suicida_sexo suicida_tr_edad  \
# 418                           NaN     Femenino           20-24
# 419                           NaN    Masculino           65-69
# 420                           NaN    Masculino           35-39
# 421                           NaN    Masculino           30-34
# 428                           NaN     Femenino           70-74
# ...                           ...          ...             ...
# 19305                         NaN     Femenino        90 y más
# 19307                         NaN     Femenino           25-29
# 19308                         NaN    Masculino           70-74
# 19309                         NaN     Femenino           50-54
# 21718                         NaN    Masculino           40-44
#
#       suicida_identidad_genero
# 418             Sin determinar
# 419             Sin determinar
# 420             Sin determinar
# 421             Sin determinar
# 428             Sin determinar
# ...                        ...
# 19305                    Mujer
# 19307                    Mujer
# 19308                    Varón
# 19309                    Mujer
# 21718                    Varón
#
# [146 rows x 23 columns]

# %% [markdown]
# Both are from `La Pampa`, which has the `42` INDEC id. However, none of our departments has a province id of `42`.

# %%
departments[departments["id_provincia_indec"] == 42]
# Out:
#      id_indec   nombre_indec  id_provincia_indec
# 284     42007        Atreucó                  42
# 285     42014    Caleu Caleu                  42
# 286     42021        Capital                  42
# 287     42028        Catriló                  42
# 288     42035        Conhelo                  42
# 289     42042         Curacó                  42
# 290     42049       Chalileo                  42
# 291     42056     Chapaleufú                  42
# 292     42063      Chical Co                  42
# 293     42070      Guatraché                  42
# 294     42077          Hucal                  42
# 295     42084   Lihuel Calel                  42
# 296     42091  Limay Mahuida                  42
# 297     42098       Loventué                  42
# 298     42105         Maracó                  42
# 299     42112         Puelén                  42
# 300     42119    Quemú Quemú                  42
# 301     42126         Rancul                  42
# 302     42133        Realicó                  42
# 303     42140           Toay                  42
# 304     42147         Trenel                  42
# 305     42154        Utracán                  42

# %% [markdown]
# We don´t have `Santa Rosa` or `25 de Mayo` departments in `La Pampa` for our INDEC table. We migth discard these rows.

# %% [markdown]
# Now, with all of this in mind, we can clean the original suicides table

# %%
comunas_rows = df_suicides[df_suicides.apply(lambda x: "Comuna" in x["departamento_nombre"], axis=1)]

# %%
comunas_ids = comunas_rows["departamento_id"].unique()

# %%
comunas_ids
# Out:
# array([2005, 2007, 2008, 2009, 2013, 2014, 2001, 2003, 2011, 2004, 2006,
#        2015, 2010, 2012, 2002])

# %%
departments
# Out:
#      id_indec            nombre_indec  id_provincia_indec
# 0        2000                    CABA                   2
# 1        6007           Adolfo Alsina                   6
# 2        6014  Adolfo Gonzales Chaves                   6
# 3        6021                 Alberti                   6
# 4        6028         Almirante Brown                   6
# ..        ...                     ...                 ...
# 505     90105              Tafí Viejo                  90
# 506     90112                 Trancas                  90
# 507     90119             Yerba Buena                  90
# 508     94007      Río Grande/Tolhuin                  94
# 509     94014                 Ushuaia                  94
#
# [510 rows x 3 columns]

# %% [markdown]
# Gonna replace those ids with `2000`

# %%
df_suicides["departamento_id"] = df_suicides["departamento_id"].replace(to_replace=comunas_ids, value=2000)

# %%
df_suicides
# Out:
#        id_hecho federal  provincia_id provincia_nombre  departamento_id  \
# 0          8529      No            42         La Pampa            42002
# 1          8530      No            42         La Pampa            42003
# 2          8569      No            78       Santa Cruz            78021
# 3          8705      No            58          Neuquén            58035
# 4          8706      No            58          Neuquén            58035
# ...         ...     ...           ...              ...              ...
# 21714     37640      No            18       Corrientes            18049
# 21715     37642      No            18       Corrientes            18070
# 21716     37643      No            18       Corrientes            18070
# 21717     37639      No            18       Corrientes            18133
# 21718     32650      No            42         La Pampa            42001
#
#         departamento_nombre localidad_id localidad_nombre  anio  mes  ...  \
# 0      Norte (General Pico)       105030     General Pico  2017    1  ...
# 1        Sur (General Acha)        70030        Guatraché  2017    1  ...
# 2                 Güer Aike           60  28 de Noviembre  2017    1  ...
# 3               Confluencia           70          Neuquén  2017    1  ...
# 4               Confluencia          100         Plottier  2017    1  ...
# ...                     ...          ...              ...   ...  ...  ...
# 21714               Esquina           10          Esquina  2022    7  ...
# 21715                  Goya           20             Goya  2022    9  ...
# 21716                  Goya           20             Goya  2022    9  ...
# 21717             San Cosme           30        San Cosme  2022    7  ...
# 21718   Centro (Santa Rosa)        21020       Santa Rosa  2022    3  ...
#
#                     tipo_lugar_ampliado                   tipo_lugar_otro  \
# 0                           Vía pública                               NaN
# 1                  Domicilio particular                               NaN
# 2                           Vía pública                               NaN
# 3      Hotel/Motel/Hospedaje temporario  Hotel/Motel/Hospedaje temporario
# 4                  Domicilio particular                               NaN
# ...                                 ...                               ...
# 21714                Cárcel o comisaría                               NaN
# 21715              Domicilio particular                               NaN
# 21716              Domicilio particular                               NaN
# 21717       Campo/descampado/zona rural       Campo/descampado/zona rural
# 21718              Domicilio particular                               NaN
#
#             modalidad modalidad_ampliado modalidad_otro  \
# 0        Ahorcamiento       Ahorcamiento            NaN
# 1       Arma de fuego      Arma de fuego            NaN
# 2        Ahorcamiento       Ahorcamiento            NaN
# 3       Arma de fuego      Arma de fuego            NaN
# 4        Ahorcamiento       Ahorcamiento            NaN
# ...               ...                ...            ...
# 21714    Ahorcamiento       Ahorcamiento            NaN
# 21715  Sin determinar     Sin determinar            NaN
# 21716    Ahorcamiento       Ahorcamiento            NaN
# 21717    Ahorcamiento       Ahorcamiento            NaN
# 21718   Arma de fuego      Arma de fuego            NaN
#
#       motivo_origen_registro motivo_origen_registro_otro suicida_sexo  \
# 0      Intervención policial                         NaN    Masculino
# 1      Intervención policial                         NaN    Masculino
# 2        Denuncia particular                         NaN    Masculino
# 3      Intervención policial                         NaN    Masculino
# 4      Intervención policial                         NaN    Masculino
# ...                      ...                         ...          ...
# 21714  Intervención policial                         NaN    Masculino
# 21715  Intervención policial                         NaN    Masculino
# 21716  Intervención policial                         NaN    Masculino
# 21717  Intervención policial                         NaN    Masculino
# 21718    Denuncia particular                         NaN    Masculino
#
#       suicida_tr_edad suicida_identidad_genero
# 0               20-24           Sin determinar
# 1               55-59           Sin determinar
# 2               15-19           Sin determinar
# 3               20-24           Sin determinar
# 4               20-24           Sin determinar
# ...               ...                      ...
# 21714           30-34                    Varón
# 21715           50-54                    Varón
# 21716           15-19                    Varón
# 21717           30-34                    Varón
# 21718           40-44                    Varón
#
# [21719 rows x 23 columns]

# %%
df_suicides.columns = ['id_hecho', 'federal', 'provincia_id', 'provincia_nombre',
       'id_indec', 'departamento_nombre', 'localidad_id',
       'localidad_nombre', 'anio', 'mes', 'fecha_hecho', 'hora_hecho',
       'tipo_lugar', 'tipo_lugar_ampliado', 'tipo_lugar_otro', 'modalidad',
       'modalidad_ampliado', 'modalidad_otro', 'motivo_origen_registro',
       'motivo_origen_registro_otro', 'suicida_sexo', 'suicida_tr_edad',
       'suicida_identidad_genero']

# %%
df_suicides_merged = pd.merge(df_suicides, departments, on="id_indec", how="left")

# %%
df_suicides_merged
# Out:
#        id_hecho federal  provincia_id provincia_nombre  id_indec  \
# 0          8529      No            42         La Pampa     42002
# 1          8530      No            42         La Pampa     42003
# 2          8569      No            78       Santa Cruz     78021
# 3          8705      No            58          Neuquén     58035
# 4          8706      No            58          Neuquén     58035
# ...         ...     ...           ...              ...       ...
# 21714     37640      No            18       Corrientes     18049
# 21715     37642      No            18       Corrientes     18070
# 21716     37643      No            18       Corrientes     18070
# 21717     37639      No            18       Corrientes     18133
# 21718     32650      No            42         La Pampa     42001
#
#         departamento_nombre localidad_id localidad_nombre  anio  mes  ...  \
# 0      Norte (General Pico)       105030     General Pico  2017    1  ...
# 1        Sur (General Acha)        70030        Guatraché  2017    1  ...
# 2                 Güer Aike           60  28 de Noviembre  2017    1  ...
# 3               Confluencia           70          Neuquén  2017    1  ...
# 4               Confluencia          100         Plottier  2017    1  ...
# ...                     ...          ...              ...   ...  ...  ...
# 21714               Esquina           10          Esquina  2022    7  ...
# 21715                  Goya           20             Goya  2022    9  ...
# 21716                  Goya           20             Goya  2022    9  ...
# 21717             San Cosme           30        San Cosme  2022    7  ...
# 21718   Centro (Santa Rosa)        21020       Santa Rosa  2022    3  ...
#
#             modalidad modalidad_ampliado modalidad_otro  \
# 0        Ahorcamiento       Ahorcamiento            NaN
# 1       Arma de fuego      Arma de fuego            NaN
# 2        Ahorcamiento       Ahorcamiento            NaN
# 3       Arma de fuego      Arma de fuego            NaN
# 4        Ahorcamiento       Ahorcamiento            NaN
# ...               ...                ...            ...
# 21714    Ahorcamiento       Ahorcamiento            NaN
# 21715  Sin determinar     Sin determinar            NaN
# 21716    Ahorcamiento       Ahorcamiento            NaN
# 21717    Ahorcamiento       Ahorcamiento            NaN
# 21718   Arma de fuego      Arma de fuego            NaN
#
#       motivo_origen_registro motivo_origen_registro_otro suicida_sexo  \
# 0      Intervención policial                         NaN    Masculino
# 1      Intervención policial                         NaN    Masculino
# 2        Denuncia particular                         NaN    Masculino
# 3      Intervención policial                         NaN    Masculino
# 4      Intervención policial                         NaN    Masculino
# ...                      ...                         ...          ...
# 21714  Intervención policial                         NaN    Masculino
# 21715  Intervención policial                         NaN    Masculino
# 21716  Intervención policial                         NaN    Masculino
# 21717  Intervención policial                         NaN    Masculino
# 21718    Denuncia particular                         NaN    Masculino
#
#       suicida_tr_edad suicida_identidad_genero nombre_indec id_provincia_indec
# 0               20-24           Sin determinar          NaN                NaN
# 1               55-59           Sin determinar          NaN                NaN
# 2               15-19           Sin determinar    Güer Aike               78.0
# 3               20-24           Sin determinar  Confluencia               58.0
# 4               20-24           Sin determinar  Confluencia               58.0
# ...               ...                      ...          ...                ...
# 21714           30-34                    Varón      Esquina               18.0
# 21715           50-54                    Varón         Goya               18.0
# 21716           15-19                    Varón         Goya               18.0
# 21717           30-34                    Varón    San Cosme               18.0
# 21718           40-44                    Varón          NaN                NaN
#
# [21719 rows x 25 columns]

# %%
suicide_cleaned_table = df_suicides_merged[~(df_suicides_merged["nombre_indec"].isna())].copy()

# %%
suicide_cleaned_table
# Out:
#        id_hecho federal  provincia_id provincia_nombre  id_indec  \
# 2          8569      No            78       Santa Cruz     78021
# 3          8705      No            58          Neuquén     58035
# 4          8706      No            58          Neuquén     58035
# 5          8707      No            58          Neuquén     58035
# 6          8708      No            58          Neuquén     58049
# ...         ...     ...           ...              ...       ...
# 21713     38831      No            14          Córdoba     14021
# 21714     37640      No            18       Corrientes     18049
# 21715     37642      No            18       Corrientes     18070
# 21716     37643      No            18       Corrientes     18070
# 21717     37639      No            18       Corrientes     18133
#
#       departamento_nombre localidad_id     localidad_nombre  anio  mes  ...  \
# 2               Güer Aike           60      28 de Noviembre  2017    1  ...
# 3             Confluencia           70              Neuquén  2017    1  ...
# 4             Confluencia          100             Plottier  2017    1  ...
# 5             Confluencia           40            Cutral Có  2017    1  ...
# 6               Huiliches           10  Junín de los Andes   2017    1  ...
# ...                   ...          ...                  ...   ...  ...  ...
# 21713               Colón          240               Saldán  2022    8  ...
# 21714             Esquina           10              Esquina  2022    7  ...
# 21715                Goya           20                 Goya  2022    9  ...
# 21716                Goya           20                 Goya  2022    9  ...
# 21717           San Cosme           30            San Cosme  2022    7  ...
#
#             modalidad modalidad_ampliado modalidad_otro  \
# 2        Ahorcamiento       Ahorcamiento            NaN
# 3       Arma de fuego      Arma de fuego            NaN
# 4        Ahorcamiento       Ahorcamiento            NaN
# 5        Ahorcamiento       Ahorcamiento            NaN
# 6        Ahorcamiento       Ahorcamiento            NaN
# ...               ...                ...            ...
# 21713    Ahorcamiento       Ahorcamiento            NaN
# 21714    Ahorcamiento       Ahorcamiento            NaN
# 21715  Sin determinar     Sin determinar            NaN
# 21716    Ahorcamiento       Ahorcamiento            NaN
# 21717    Ahorcamiento       Ahorcamiento            NaN
#
#       motivo_origen_registro motivo_origen_registro_otro suicida_sexo  \
# 2        Denuncia particular                         NaN    Masculino
# 3      Intervención policial                         NaN    Masculino
# 4      Intervención policial                         NaN    Masculino
# 5      Intervención policial                         NaN    Masculino
# 6      Intervención policial                         NaN    Masculino
# ...                      ...                         ...          ...
# 21713  Intervención policial                         NaN     Femenino
# 21714  Intervención policial                         NaN    Masculino
# 21715  Intervención policial                         NaN    Masculino
# 21716  Intervención policial                         NaN    Masculino
# 21717  Intervención policial                         NaN    Masculino
#
#       suicida_tr_edad suicida_identidad_genero nombre_indec id_provincia_indec
# 2               15-19           Sin determinar    Güer Aike               78.0
# 3               20-24           Sin determinar  Confluencia               58.0
# 4               20-24           Sin determinar  Confluencia               58.0
# 5               20-24           Sin determinar  Confluencia               58.0
# 6               45-49           Sin determinar    Huiliches               58.0
# ...               ...                      ...          ...                ...
# 21713           15-19                    Mujer        Colón               14.0
# 21714           30-34                    Varón      Esquina               18.0
# 21715           50-54                    Varón         Goya               18.0
# 21716           15-19                    Varón         Goya               18.0
# 21717           30-34                    Varón    San Cosme               18.0
#
# [21426 rows x 25 columns]

# %% [markdown]
# `21426` of the `21719` rows, that corresponds to 98.65% of the data original data retained. We can continue with this and assume a really small loss.

# %% [markdown]
# All the `departamento_id` values correspond to valid INDEC ones, we can drop the provinces (they can be recovered using the departments) and other columns that are not longer useful.

# %%
suicide_cleaned_table.columns
# Out:
# Index(['id_hecho', 'federal', 'provincia_id', 'provincia_nombre', 'id_indec',
#        'departamento_nombre', 'localidad_id', 'localidad_nombre', 'anio',
#        'mes', 'fecha_hecho', 'hora_hecho', 'tipo_lugar', 'tipo_lugar_ampliado',
#        'tipo_lugar_otro', 'modalidad', 'modalidad_ampliado', 'modalidad_otro',
#        'motivo_origen_registro', 'motivo_origen_registro_otro', 'suicida_sexo',
#        'suicida_tr_edad', 'suicida_identidad_genero', 'nombre_indec',
#        'id_provincia_indec'],
#       dtype='object')

# %%
useful_cols = ['id_hecho', 'id_indec', 'fecha_hecho', 'hora_hecho', 'tipo_lugar', 'modalidad',
       'motivo_origen_registro', 'suicida_sexo',
       'suicida_tr_edad', 'suicida_identidad_genero']

# %%
suicide_cleaned_table = suicide_cleaned_table[useful_cols]

# %%
suicide_cleaned_table
# Out:
#        id_hecho  id_indec fecha_hecho hora_hecho                  tipo_lugar  \
# 2          8569     78021  01-01-2017   19:00:00                 Vía pública
# 3          8705     58035  31-01-2017   17:30:00  Otro Lugar ( Especificar )
# 4          8706     58035  31-01-2017   22:40:00        Domicilio particular
# 5          8707     58035  29-01-2017   20:30:00        Domicilio particular
# 6          8708     58049  02-01-2017   14:25:00        Domicilio particular
# ...         ...       ...         ...        ...                         ...
# 21713     38831     14021  28-08-2022   11:11:11        Domicilio particular
# 21714     37640     18049  09-07-2022   07:30:00          Cárcel o comisaría
# 21715     37642     18070  11-09-2022   05:00:00        Domicilio particular
# 21716     37643     18070  27-09-2022   06:45:00        Domicilio particular
# 21717     37639     18133  15-07-2022   08:45:00  Otro Lugar ( Especificar )
#
#             modalidad motivo_origen_registro suicida_sexo suicida_tr_edad  \
# 2        Ahorcamiento    Denuncia particular    Masculino           15-19
# 3       Arma de fuego  Intervención policial    Masculino           20-24
# 4        Ahorcamiento  Intervención policial    Masculino           20-24
# 5        Ahorcamiento  Intervención policial    Masculino           20-24
# 6        Ahorcamiento  Intervención policial    Masculino           45-49
# ...               ...                    ...          ...             ...
# 21713    Ahorcamiento  Intervención policial     Femenino           15-19
# 21714    Ahorcamiento  Intervención policial    Masculino           30-34
# 21715  Sin determinar  Intervención policial    Masculino           50-54
# 21716    Ahorcamiento  Intervención policial    Masculino           15-19
# 21717    Ahorcamiento  Intervención policial    Masculino           30-34
#
#       suicida_identidad_genero
# 2               Sin determinar
# 3               Sin determinar
# 4               Sin determinar
# 5               Sin determinar
# 6               Sin determinar
# ...                        ...
# 21713                    Mujer
# 21714                    Varón
# 21715                    Varón
# 21716                    Varón
# 21717                    Varón
#
# [21426 rows x 10 columns]

# %% [markdown]
# Now we need to rename them.

# %%
new_col_names = ["id_hecho", "id_departamento_indec", "fecha", "hora", "lugar",
                 "modalidad", "origen_registro", "suicida_sexo", "suicida_rango_edad", "suicida_identidad_genero"]

# %%
suicide_cleaned_table.columns = new_col_names

# %%
suicide_cleaned_table
# Out:
#        id_hecho  id_departamento_indec       fecha      hora  \
# 2          8569                  78021  01-01-2017  19:00:00
# 3          8705                  58035  31-01-2017  17:30:00
# 4          8706                  58035  31-01-2017  22:40:00
# 5          8707                  58035  29-01-2017  20:30:00
# 6          8708                  58049  02-01-2017  14:25:00
# ...         ...                    ...         ...       ...
# 21713     38831                  14021  28-08-2022  11:11:11
# 21714     37640                  18049  09-07-2022  07:30:00
# 21715     37642                  18070  11-09-2022  05:00:00
# 21716     37643                  18070  27-09-2022  06:45:00
# 21717     37639                  18133  15-07-2022  08:45:00
#
#                             lugar       modalidad        origen_registro  \
# 2                     Vía pública    Ahorcamiento    Denuncia particular
# 3      Otro Lugar ( Especificar )   Arma de fuego  Intervención policial
# 4            Domicilio particular    Ahorcamiento  Intervención policial
# 5            Domicilio particular    Ahorcamiento  Intervención policial
# 6            Domicilio particular    Ahorcamiento  Intervención policial
# ...                           ...             ...                    ...
# 21713        Domicilio particular    Ahorcamiento  Intervención policial
# 21714          Cárcel o comisaría    Ahorcamiento  Intervención policial
# 21715        Domicilio particular  Sin determinar  Intervención policial
# 21716        Domicilio particular    Ahorcamiento  Intervención policial
# 21717  Otro Lugar ( Especificar )    Ahorcamiento  Intervención policial
#
#       suicida_sexo suicida_rango_edad suicida_identidad_genero
# 2        Masculino              15-19           Sin determinar
# 3        Masculino              20-24           Sin determinar
# 4        Masculino              20-24           Sin determinar
# 5        Masculino              20-24           Sin determinar
# 6        Masculino              45-49           Sin determinar
# ...            ...                ...                      ...
# 21713     Femenino              15-19                    Mujer
# 21714    Masculino              30-34                    Varón
# 21715    Masculino              50-54                    Varón
# 21716    Masculino              15-19                    Varón
# 21717    Masculino              30-34                    Varón
#
# [21426 rows x 10 columns]

# %%
suicides = suicide_cleaned_table.copy()

# %%
del df_suicides, suicide_cleaned_table, new_col_names, merged_departments, useful_cols, df_suicides_merged, comunas_ids, comunas_rows, incorrect_pairs, suicides_departments

# %%
suicides
# Out:
#        id_hecho  id_departamento_indec       fecha      hora  \
# 2          8569                  78021  01-01-2017  19:00:00
# 3          8705                  58035  31-01-2017  17:30:00
# 4          8706                  58035  31-01-2017  22:40:00
# 5          8707                  58035  29-01-2017  20:30:00
# 6          8708                  58049  02-01-2017  14:25:00
# ...         ...                    ...         ...       ...
# 21713     38831                  14021  28-08-2022  11:11:11
# 21714     37640                  18049  09-07-2022  07:30:00
# 21715     37642                  18070  11-09-2022  05:00:00
# 21716     37643                  18070  27-09-2022  06:45:00
# 21717     37639                  18133  15-07-2022  08:45:00
#
#                             lugar       modalidad        origen_registro  \
# 2                     Vía pública    Ahorcamiento    Denuncia particular
# 3      Otro Lugar ( Especificar )   Arma de fuego  Intervención policial
# 4            Domicilio particular    Ahorcamiento  Intervención policial
# 5            Domicilio particular    Ahorcamiento  Intervención policial
# 6            Domicilio particular    Ahorcamiento  Intervención policial
# ...                           ...             ...                    ...
# 21713        Domicilio particular    Ahorcamiento  Intervención policial
# 21714          Cárcel o comisaría    Ahorcamiento  Intervención policial
# 21715        Domicilio particular  Sin determinar  Intervención policial
# 21716        Domicilio particular    Ahorcamiento  Intervención policial
# 21717  Otro Lugar ( Especificar )    Ahorcamiento  Intervención policial
#
#       suicida_sexo suicida_rango_edad suicida_identidad_genero
# 2        Masculino              15-19           Sin determinar
# 3        Masculino              20-24           Sin determinar
# 4        Masculino              20-24           Sin determinar
# 5        Masculino              20-24           Sin determinar
# 6        Masculino              45-49           Sin determinar
# ...            ...                ...                      ...
# 21713     Femenino              15-19                    Mujer
# 21714    Masculino              30-34                    Varón
# 21715    Masculino              50-54                    Varón
# 21716    Masculino              15-19                    Varón
# 21717    Masculino              30-34                    Varón
#
# [21426 rows x 10 columns]

# %% [markdown]
# That should be enough for this dataset by now.

# %% [markdown]
# ### Mean Income

# %% [markdown]
# The only thing that we have to validate here, at the beginning, is that the indec departments are correct. We can see that there are a bunch on `NaN`s just printing the head and tail of the dataframe.

# %%
df_mean_income
# Out:
#               fecha  codigo_departamento_indec  id_provincia_indec  clae2  \
# 0        2014-01-01                     2000.0                 2.0      1
# 1        2014-01-01                     2000.0                 2.0      2
# 2        2014-01-01                     2000.0                 2.0      3
# 3        2014-01-01                     2000.0                 2.0      5
# 4        2014-01-01                     2000.0                 2.0      6
# ...             ...                        ...                 ...    ...
# 3597476  2023-09-01                        NaN                 NaN     93
# 3597477  2023-09-01                        NaN                 NaN     94
# 3597478  2023-09-01                        NaN                 NaN     95
# 3597479  2023-09-01                        NaN                 NaN     96
# 3597480  2023-09-01                        NaN                 NaN    999
#
#          w_mean
# 0         13085
# 1         10081
# 2         17837
# 3         57688
# 4         62211
# ...         ...
# 3597476  247445
# 3597477  363199
# 3597478  196750
# 3597479  231747
# 3597480  402849
#
# [3597481 rows x 5 columns]

# %%
df_mean_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3597481 entries, 0 to 3597480
# Data columns (total 5 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   fecha                      object
#  1   codigo_departamento_indec  float64
#  2   id_provincia_indec         float64
#  3   clae2                      int64
#  4   w_mean                     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 137.2+ MB

# %% [markdown]
# Both the province and departments ids are using float64 datatype, it should be an int.

# %%
df_mean_income["codigo_departamento_indec"].unique()
# Out:
# array([ 2000.,  6007.,  6014.,  6021.,  6028.,  6035.,  6042.,  6049.,
#         6056.,  6063.,  6070.,  6077.,  6084.,  6091.,  6098.,  6105.,
#         6112.,  6119.,  6126.,  6134.,  6140.,  6147.,  6154.,  6161.,
#         6168.,  6175.,  6182.,  6189.,  6196.,  6203.,  6210.,  6217.,
#         6224.,  6231.,  6238.,  6245.,  6252.,  6260.,  6266.,  6270.,
#         6274.,  6277.,  6280.,  6287.,  6294.,  6301.,  6308.,  6315.,
#         6322.,  6329.,  6336.,  6343.,  6351.,  6357.,  6364.,  6371.,
#         6385.,  6392.,  6399.,  6406.,  6408.,  6410.,  6412.,  6413.,
#         6420.,  6427.,  6434.,  6441.,  6448.,  6455.,  6462.,  6469.,
#         6476.,  6483.,  6490.,  6497.,  6505.,  6511.,  6515.,  6518.,
#         6525.,  6532.,  6539.,  6547.,  6553.,  6560.,  6568.,  6574.,
#         6581.,  6588.,  6595.,  6602.,  6609.,  6616.,  6623.,  6630.,
#         6638.,  6644.,  6648.,  6651.,  6655.,  6658.,  6665.,  6672.,
#         6679.,  6686.,  6693.,  6700.,  6707.,  6714.,  6721.,  6728.,
#         6735.,  6742.,  6749.,  6756.,  6760.,  6763.,  6770.,  6778.,
#         6784.,  6791.,  6798.,  6805.,  6812.,  6819.,  6826.,  6833.,
#         6840.,  6847.,  6854.,  6861.,  6868.,  6875.,  6882., 10007.,
#        10014., 10021., 10028., 10035., 10042., 10049., 10056., 10063.,
#        10070., 10077., 10084., 10091., 10098., 10105., 10112., 14007.,
#        14014., 14021., 14028., 14035., 14042., 14049., 14056., 14063.,
#        14070., 14077., 14084., 14091., 14098., 14105., 14112., 14119.,
#        14126., 14133., 14140., 14147., 14154., 14161., 14168., 14175.,
#        14182., 18007., 18014., 18021., 18028., 18035., 18042., 18049.,
#        18056., 18063., 18070., 18077., 18084., 18091., 18098., 18105.,
#        18112., 18119., 18126., 18133., 18140., 18147., 18154., 18161.,
#        18168., 18175., 22007., 22014., 22021., 22028., 22036., 22039.,
#        22043., 22049., 22056., 22063., 22070., 22077., 22084., 22091.,
#        22098., 22105., 22112., 22119., 22126., 22133., 22140., 22147.,
#        22154., 22168., 26007., 26014., 26021., 26028., 26035., 26042.,
#        26056., 26063., 26070., 26077., 26084., 26091., 26098., 26105.,
#        30008., 30015., 30021., 30028., 30035., 30042., 30049., 30056.,
#        30063., 30070., 30077., 30084., 30088., 30091., 30098., 30105.,
#        30113., 34007., 34014., 34021., 34028., 34035., 34042., 34049.,
#        34056., 38007., 38014., 38021., 38028., 38035., 38042., 38049.,
#        38056., 38063., 38070., 38077., 38084., 38094., 38098., 38105.,
#        38112., 42007., 42014., 42021., 42028., 42035., 42056., 42063.,
#        42070., 42077., 42098., 42105., 42112., 42119., 42126., 42133.,
#        42140., 42147., 42154., 46007., 46014., 46021., 46028., 46035.,
#        46042., 46049., 46056., 46063., 46070., 46077., 46084., 46091.,
#        46098., 46105., 46112., 46119., 50007., 50014., 50021., 50028.,
#        50035., 50042., 50049., 50056., 50063., 50070., 50077., 50084.,
#        50091., 50098., 50105., 50112., 50119., 50126., 54007., 54014.,
#        54021., 54028., 54035., 54042., 54049., 54056., 54063., 54070.,
#        54077., 54084., 54091., 54098., 54105., 54112., 54119., 58007.,
#        58014., 58021., 58028., 58035., 58042., 58049., 58056., 58063.,
#        58070., 58077., 58084., 58091., 58098., 58105., 58112., 62007.,
#        62014., 62021., 62028., 62035., 62042., 62049., 62056., 62063.,
#        62070., 62077., 62084., 62091., 66007., 66014., 66021., 66028.,
#        66035., 66042., 66049., 66056., 66063., 66070., 66084., 66091.,
#        66098., 66105., 66112., 66119., 66126., 66133., 66140., 66147.,
#        66154., 70007., 70014., 70021., 70028., 70035., 70042., 70049.,
#        70056., 70063., 70070., 70077., 70084., 70091., 70098., 70105.,
#        70112., 70119., 70126., 70133., 74007., 74014., 74021., 74028.,
#        74035., 74042., 74049., 74056., 74063., 78007., 78014., 78021.,
#        78028., 78035., 78042., 78049., 82007., 82014., 82021., 82028.,
#        82035., 82042., 82049., 82056., 82063., 82070., 82077., 82084.,
#        82091., 82098., 82105., 82112., 82119., 82126., 82133., 86007.,
#        86014., 86021., 86028., 86035., 86042., 86049., 86056., 86063.,
#        86070., 86077., 86084., 86091., 86098., 86105., 86112., 86119.,
#        86126., 86133., 86140., 86147., 86154., 86161., 86168., 86175.,
#        86182., 86189., 90007., 90014., 90021., 90028., 90035., 90042.,
#        90049., 90056., 90063., 90070., 90077., 90084., 90091., 90098.,
#        90105., 90112., 90119., 94007., 94014.,    nan, 46126., 42049.,
#        66161., 34063.])

# %%
df_mean_income[df_mean_income["codigo_departamento_indec"].isna()]
# Out:
#               fecha  codigo_departamento_indec  id_provincia_indec  clae2  \
# 30910    2014-01-01                        NaN                 NaN      1
# 30911    2014-01-01                        NaN                 NaN      2
# 30912    2014-01-01                        NaN                 NaN      3
# 30913    2014-01-01                        NaN                 NaN      6
# 30914    2014-01-01                        NaN                 NaN      7
# ...             ...                        ...                 ...    ...
# 3597476  2023-09-01                        NaN                 NaN     93
# 3597477  2023-09-01                        NaN                 NaN     94
# 3597478  2023-09-01                        NaN                 NaN     95
# 3597479  2023-09-01                        NaN                 NaN     96
# 3597480  2023-09-01                        NaN                 NaN    999
#
#          w_mean
# 30910      4933
# 30911      2641
# 30912     15357
# 30913     41990
# 30914     20778
# ...         ...
# 3597476  247445
# 3597477  363199
# 3597478  196750
# 3597479  231747
# 3597480  402849
#
# [9828 rows x 5 columns]

# %% [markdown]
# These can be problematic, we will focus on the ones that are not `NaN`

# %%
df_mean_income.dropna(inplace=True)

# %%
df_mean_income
# Out:
#               fecha  codigo_departamento_indec  id_provincia_indec  clae2  \
# 0        2014-01-01                     2000.0                 2.0      1
# 1        2014-01-01                     2000.0                 2.0      2
# 2        2014-01-01                     2000.0                 2.0      3
# 3        2014-01-01                     2000.0                 2.0      5
# 4        2014-01-01                     2000.0                 2.0      6
# ...             ...                        ...                 ...    ...
# 3597392  2023-09-01                    94014.0                94.0     93
# 3597393  2023-09-01                    94014.0                94.0     94
# 3597394  2023-09-01                    94014.0                94.0     95
# 3597395  2023-09-01                    94014.0                94.0     96
# 3597396  2023-09-01                    94014.0                94.0    999
#
#          w_mean
# 0         13085
# 1         10081
# 2         17837
# 3         57688
# 4         62211
# ...         ...
# 3597392  536119
# 3597393  504914
# 3597394  367788
# 3597395  316829
# 3597396  711491
#
# [3587653 rows x 5 columns]

# %% [markdown]
# 3587653 of the 3597481 rows preserved, that is 99.73% of the data. We will need to check about the completness of the dataset then, because if it was a full year that was dropped, then it could be problematic.

# %%
df_mean_income[["codigo_departamento_indec", "id_provincia_indec"]] = df_mean_income[["codigo_departamento_indec", "id_provincia_indec"]].astype(int)

# %%
df_mean_income
# Out:
#               fecha  codigo_departamento_indec  id_provincia_indec  clae2  \
# 0        2014-01-01                       2000                   2      1
# 1        2014-01-01                       2000                   2      2
# 2        2014-01-01                       2000                   2      3
# 3        2014-01-01                       2000                   2      5
# 4        2014-01-01                       2000                   2      6
# ...             ...                        ...                 ...    ...
# 3597392  2023-09-01                      94014                  94     93
# 3597393  2023-09-01                      94014                  94     94
# 3597394  2023-09-01                      94014                  94     95
# 3597395  2023-09-01                      94014                  94     96
# 3597396  2023-09-01                      94014                  94    999
#
#          w_mean
# 0         13085
# 1         10081
# 2         17837
# 3         57688
# 4         62211
# ...         ...
# 3597392  536119
# 3597393  504914
# 3597394  367788
# 3597395  316829
# 3597396  711491
#
# [3587653 rows x 5 columns]

# %%
df_mean_income.rename(columns={"codigo_departamento_indec":"id_indec"},inplace=True)

# %%
merged_income = pd.merge(df_mean_income, departments, on="id_indec", how="left")

# %%
merged_income
# Out:
#               fecha  id_indec  id_provincia_indec_x  clae2  w_mean  \
# 0        2014-01-01      2000                     2      1   13085
# 1        2014-01-01      2000                     2      2   10081
# 2        2014-01-01      2000                     2      3   17837
# 3        2014-01-01      2000                     2      5   57688
# 4        2014-01-01      2000                     2      6   62211
# ...             ...       ...                   ...    ...     ...
# 3587648  2023-09-01     94014                    94     93  536119
# 3587649  2023-09-01     94014                    94     94  504914
# 3587650  2023-09-01     94014                    94     95  367788
# 3587651  2023-09-01     94014                    94     96  316829
# 3587652  2023-09-01     94014                    94    999  711491
#
#         nombre_indec  id_provincia_indec_y
# 0               CABA                     2
# 1               CABA                     2
# 2               CABA                     2
# 3               CABA                     2
# 4               CABA                     2
# ...              ...                   ...
# 3587648      Ushuaia                    94
# 3587649      Ushuaia                    94
# 3587650      Ushuaia                    94
# 3587651      Ushuaia                    94
# 3587652      Ushuaia                    94
#
# [3587653 rows x 7 columns]

# %%
merged_income.isna().sum()
# Out:
# fecha                   0
# id_indec                0
# id_provincia_indec_x    0
# clae2                   0
# w_mean                  0
# nombre_indec            0
# id_provincia_indec_y    0
# dtype: int64

# %% [markdown]
# Everything is good, let´s just select the columns that we are going to use and it will be done.

# %%
useful_cols = ['fecha', 'id_indec', 'clae2', 'w_mean']

# %%
mean_income = df_mean_income[useful_cols].copy()

# %%
mean_income.columns = ["fecha", "id_departamento_indec", "clae2", "w_mean"]

# %%
mean_income
# Out:
#               fecha  id_departamento_indec  clae2  w_mean
# 0        2014-01-01                   2000      1   13085
# 1        2014-01-01                   2000      2   10081
# 2        2014-01-01                   2000      3   17837
# 3        2014-01-01                   2000      5   57688
# 4        2014-01-01                   2000      6   62211
# ...             ...                    ...    ...     ...
# 3597392  2023-09-01                  94014     93  536119
# 3597393  2023-09-01                  94014     94  504914
# 3597394  2023-09-01                  94014     95  367788
# 3597395  2023-09-01                  94014     96  316829
# 3597396  2023-09-01                  94014    999  711491
#
# [3587653 rows x 4 columns]

# %%
del df_mean_income, useful_cols, merged_income

# %% [markdown]
# ### CLAE dictionary

# %% [markdown]
# We just need to select the columns that we will use.

# %%
df_clae2
# Out:
#     clae2                                         clae2_desc letra  \
# 0       1  Agricultura, ganadería, caza y servicios relac...     A
# 1       2                Silvicultura y explotación forestal     A
# 2       3                                Pesca y acuicultura     A
# 3       5                     Extracción de carbón y lignito     B
# 4       6         Extracción de petróleo crudo y gas natural     B
# ..    ...                                                ...   ...
# 81     93  Actividades deportivas, recreativas y de entre...     R
# 82     94                          Servicios de asociaciones     S
# 83     95  Reparación de computadoras y equipos de uso do...     S
# 84     96                         Otros servicios personales     S
# 85    999                                     Otros sectores   NaN
#
#                                            letra_desc
# 0    AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y ...
# 1    AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y ...
# 2    AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y ...
# 3                     EXPLOTACION DE MINAS Y CANTERAS
# 4                     EXPLOTACION DE MINAS Y CANTERAS
# ..                                                ...
# 81   SERVICIOS  ARTÍSTICOS, CULTURALES, DEPORTIVOS...
# 82   SERVICIOS DE ASOCIACIONES Y SERVICIOS PERSONA...
# 83   SERVICIOS DE ASOCIACIONES Y SERVICIOS PERSONA...
# 84   SERVICIOS DE ASOCIACIONES Y SERVICIOS PERSONA...
# 85                                              OTROS
#
# [86 rows x 4 columns]

# %%
df_clae2 = df_clae2[["clae2", "clae2_desc"]].drop_duplicates()

# %%
df_clae2
# Out:
#     clae2                                         clae2_desc
# 0       1  Agricultura, ganadería, caza y servicios relac...
# 1       2                Silvicultura y explotación forestal
# 2       3                                Pesca y acuicultura
# 3       5                     Extracción de carbón y lignito
# 4       6         Extracción de petróleo crudo y gas natural
# ..    ...                                                ...
# 81     93  Actividades deportivas, recreativas y de entre...
# 82     94                          Servicios de asociaciones
# 83     95  Reparación de computadoras y equipos de uso do...
# 84     96                         Otros servicios personales
# 85    999                                     Otros sectores
#
# [86 rows x 2 columns]

# %%
clae2 = df_clae2.copy()

# %%
del df_clae2

# %% [markdown]
# ## Checking out inconsistencies in each dataset

# %% [markdown]
# We mapped our datasets to the model that follows ERD that we saw before, now we have to check that the data is useful on each of them. Eliminate typos, handle missing values and so on.

# %% [markdown]
# ### Provinces

# %%
provinces
# Out:
#    id_indec         nombre_indec
# 0         2                 CABA
# 1         6         Buenos Aires
# 2        10            Catamarca
# 3        14              Cordoba
# 4        18           Corrientes
# 5        22                Chaco
# 6        26               Chubut
# 7        30           Entre Rios
# 8        34              Formosa
# 9        38                Jujuy
# 10       42             La Pampa
# 11       46             La Rioja
# 12       50              Mendoza
# 13       54             Misiones
# 14       58              Neuquen
# 15       62            Rio Negro
# 16       66                Salta
# 17       70             San Juan
# 18       74             San Luis
# 19       78           Santa Cruz
# 20       82             Santa Fe
# 21       86  Santiago Del Estero
# 22       90              Tucuman
# 23       94     Tierra Del Fuego

# %%
provinces.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (id_indec,)      24 non-null     int64
#  1   (nombre_indec,)  24 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 512.0+ bytes

# %% [markdown]
# Nothing to change here.

# %% [markdown]
# ### Departments

# %%
departments
# Out:
#      id_indec            nombre_indec  id_provincia_indec
# 0        2000                    CABA                   2
# 1        6007           Adolfo Alsina                   6
# 2        6014  Adolfo Gonzales Chaves                   6
# 3        6021                 Alberti                   6
# 4        6028         Almirante Brown                   6
# ..        ...                     ...                 ...
# 505     90105              Tafí Viejo                  90
# 506     90112                 Trancas                  90
# 507     90119             Yerba Buena                  90
# 508     94007      Río Grande/Tolhuin                  94
# 509     94014                 Ushuaia                  94
#
# [510 rows x 3 columns]

# %%
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_indec            510 non-null    int64
#  1   nombre_indec        510 non-null    object
#  2   id_provincia_indec  510 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 12.1+ KB

# %% [markdown]
# Everything is ok.

# %% [markdown]
# ### Crimes

# %%
crimes
# Out:
#        id_provincia_indec  anio id_snic  \
# 0                       2  2000       1
# 1                       2  2000       2
# 2                       2  2000       3
# 3                       2  2000       4
# 4                       2  2000       5
# ...                   ...   ...     ...
# 21339                  94  2022    29_7
# 21340                  94  2022    29_8
# 21341                  94  2022      30
# 21342                  94  2022      31
# 21343                  94  2022      32
#
#                                              nombre_snic  cantidad_hechos  \
# 0                                     Homicidios dolosos              149
# 1               Homicidios dolosos en grado de tentativa               54
# 2                           Muertes en accidentes viales              121
# 3                   Homicidios culposos por otros hechos               35
# 4                                       Lesiones dolosas            13154
# ...                                                  ...              ...
# 21339  Contrabando de elementos nucleares agresivos q...                0
# 21340  Otros delitos previstos en leyes especiales n,c,p             3082
# 21341                                    Contravenciones              557
# 21342                             Suicidios (consumados)               22
# 21343     Delitos contra el orden económico y financiero                2
#
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 0                  158.0                   121.0                   37.0
# 1                   58.0                    40.0                   18.0
# 2                  126.0                    97.0                   29.0
# 3                   36.0                    20.0                   13.0
# 4                13732.0                  8105.0                 5485.0
# ...                  ...                     ...                    ...
# 21339                NaN                     NaN                    NaN
# 21340                NaN                     NaN                    NaN
# 21341                NaN                     NaN                    NaN
# 21342               22.0                    12.0                   10.0
# 21343                NaN                     NaN                    NaN
#
#        cantidad_victimas_sd tasa_hechos tasa_victimas tasa_victimas_masc  \
# 0                       0.0   4,9750013     5,2755051          8,8257008
# 1                       0.0   1,8030207     1,9365778          2,9175868
# 2                       0.0    4,040102     4,2070484          7,0751481
# 3                       3.0   1,1686245     1,2020137          1,4587934
# 4                     142.0   439,20248     458,50146          591,17603
# ...                     ...         ...           ...                ...
# 21339                   NaN           0           NaN                NaN
# 21340                   NaN   1693,5648           NaN                NaN
# 21341                   NaN   306,07254           NaN                NaN
# 21342                   0.0   13,150816     13,150816          14,091123
# 21343                   NaN   1,0990038           NaN                NaN
#
#       tasa_victimas_fem
# 0             2,2783601
# 1             1,1083914
# 2             1,7857418
# 3             ,80050492
# 4              337,7515
# ...                 ...
# 21339               NaN
# 21340               NaN
# 21341               NaN
# 21342         12,175818
# 21343               NaN
#
# [21344 rows x 13 columns]

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21344 entries, 0 to 21343
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_provincia_indec      21344 non-null  int64
#  1   anio                    21344 non-null  int64
#  2   id_snic                 21344 non-null  object
#  3   nombre_snic             21344 non-null  object
#  4   cantidad_hechos         21344 non-null  int64
#  5   cantidad_victimas       7608 non-null   float64
#  6   cantidad_victimas_masc  7608 non-null   float64
#  7   cantidad_victimas_fem   7608 non-null   float64
#  8   cantidad_victimas_sd    7608 non-null   float64
#  9   tasa_hechos             21344 non-null  object
#  10  tasa_victimas           7608 non-null   object
#  11  tasa_victimas_masc      7608 non-null   object
#  12  tasa_victimas_fem       7608 non-null   object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# There is missing data in the `victims` related columns. As is is the same for each type, this would probably be because there are some crimes that doesn´t have any registered victim. Therefore, there won´t be registers for their sex or the proportions (`tasa` related columns)

# %%
missing_val_crimes = crimes[crimes["cantidad_victimas"].isna()]

# %%
missing_val_crimes
# Out:
#        id_provincia_indec  anio id_snic  \
# 11                      2  2000      12
# 12                      2  2000      13
# 14                      2  2000      15
# 15                      2  2000      16
# 16                      2  2000      17
# ...                   ...   ...     ...
# 21338                  94  2022    29_6
# 21339                  94  2022    29_7
# 21340                  94  2022    29_8
# 21341                  94  2022      30
# 21343                  94  2022      32
#
#                                              nombre_snic  cantidad_hechos  \
# 11                        Delitos contra el estado civil                1
# 12                                              Amenazas            11034
# 14     Robos (excluye los agravados por el resultado ...            68937
# 15     Tentativas de robo (excluye las agravadas por ...             2620
# 16     Robos agravados por el resultado de lesiones y...               37
# ...                                                  ...              ...
# 21338                               Contrabando agravado               23
# 21339  Contrabando de elementos nucleares agresivos q...                0
# 21340  Otros delitos previstos en leyes especiales n,c,p             3082
# 21341                                    Contravenciones              557
# 21343     Delitos contra el orden económico y financiero                2
#
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 11                   NaN                     NaN                    NaN
# 12                   NaN                     NaN                    NaN
# 14                   NaN                     NaN                    NaN
# 15                   NaN                     NaN                    NaN
# 16                   NaN                     NaN                    NaN
# ...                  ...                     ...                    ...
# 21338                NaN                     NaN                    NaN
# 21339                NaN                     NaN                    NaN
# 21340                NaN                     NaN                    NaN
# 21341                NaN                     NaN                    NaN
# 21343                NaN                     NaN                    NaN
#
#        cantidad_victimas_sd tasa_hechos tasa_victimas tasa_victimas_masc  \
# 11                      NaN   ,03338927           NaN                NaN
# 12                      NaN   368,41724           NaN                NaN
# 14                      NaN   2301,7561           NaN                NaN
# 15                      NaN   87,479889           NaN                NaN
# 16                      NaN   1,2354031           NaN                NaN
# ...                     ...         ...           ...                ...
# 21338                   NaN   12,638543           NaN                NaN
# 21339                   NaN           0           NaN                NaN
# 21340                   NaN   1693,5648           NaN                NaN
# 21341                   NaN   306,07254           NaN                NaN
# 21343                   NaN   1,0990038           NaN                NaN
#
#       tasa_victimas_fem
# 11                  NaN
# 12                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# ...                 ...
# 21338               NaN
# 21339               NaN
# 21340               NaN
# 21341               NaN
# 21343               NaN
#
# [13736 rows x 13 columns]

# %%
missing_val_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13736 entries, 11 to 21343
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_provincia_indec      13736 non-null  int64
#  1   anio                    13736 non-null  int64
#  2   id_snic                 13736 non-null  object
#  3   nombre_snic             13736 non-null  object
#  4   cantidad_hechos         13736 non-null  int64
#  5   cantidad_victimas       0 non-null      float64
#  6   cantidad_victimas_masc  0 non-null      float64
#  7   cantidad_victimas_fem   0 non-null      float64
#  8   cantidad_victimas_sd    0 non-null      float64
#  9   tasa_hechos             13736 non-null  object
#  10  tasa_victimas           0 non-null      object
#  11  tasa_victimas_masc      0 non-null      object
#  12  tasa_victimas_fem       0 non-null      object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# That's what we have guessed, if `cantidad_victimas` is missing, then it would be possible to calculate the others `victim` columns.
#
# But does this column has missing values? It is because the amount of victimas that can be considered directly affected by the crime are `zero` or is because they cannot be measured?
#
# The [User manual](https://minsegar-my.sharepoint.com/personal/dnec_minseg_gob_ar/Documents/Argentina.gob.ar/Bases/Bases%20SNIC/Manual%20de%20Usuario%20Base%20SNIC/Manual_de_usuario_Base_SNIC_2023.pdf?ga=1) of the original dataset, says in relation to the page 33:
#
# "
# Sólo disponible para los tipos de delitos: 1_Homicidios
# dolosos, 2_Homicidios dolosos en grado de tentativa,
# 3_Muertes en Accidentes Viales, 4_Homicidios culposos
# por otros hechos, 5_Lesiones dolosas, 6_Lesiones
# culposas en Accidentes Viales, 7_Lesiones culposas por
# otros hechos, 8_Otros delitos contra las personas,
# 9_Delitos contra el honor, 10_Violaciones, 11_Otros
# delitos contra la integridad sexual, 14_Otros delitos
# contra la libertad, 14_1 Trata de personas simple, 14_2
# Trata de personas agravado, 14_3 Otros delitos contra la
# libertad, 31_Suicidios (consumados).
# En los casos en que la jurisdicción envió información
# rectificada a nivel total provincial o sin desagregación
# por sexo, se asignaron las cantidades a víctimas con
# sexo sin determinar.
# "
#
# So there is a systematic missing of this values and it covers more than 50% of the dataset rows. They are simply not provided.
#
# Let´s see how much of the total sum of crimes those missing values represent.

# %%
non_missing_val_crimes = crimes[~(crimes["cantidad_victimas"].isna())]

# %%
missing_val_crimes_sum = missing_val_crimes["cantidad_hechos"].sum()
non_missing_val_crimes_sum = non_missing_val_crimes["cantidad_hechos"].sum()

# %%
print(f"There are {missing_val_crimes_sum} registered values with missing values for the victims")
print(f"There are {non_missing_val_crimes_sum} registered values with NON missing values for the victims")
# Out:
# There are 29044815 registered values with missing values for the victims
# There are 7160626 registered values with NON missing values for the victims

# %% [markdown]
# There are a lot of crimes with missing values for the victims. So drop them doesn´t seems like a good idea. They can tell us a lot about the amount of crime in an specific province.
#
# We will keep them, we just have to be careful with this in the Analysis part.

# %% [markdown]
# We just need to change some datatypes that are incorrect.

# %%
crimes
# Out:
#        id_provincia_indec  anio id_snic  \
# 0                       2  2000       1
# 1                       2  2000       2
# 2                       2  2000       3
# 3                       2  2000       4
# 4                       2  2000       5
# ...                   ...   ...     ...
# 21339                  94  2022    29_7
# 21340                  94  2022    29_8
# 21341                  94  2022      30
# 21342                  94  2022      31
# 21343                  94  2022      32
#
#                                              nombre_snic  cantidad_hechos  \
# 0                                     Homicidios dolosos              149
# 1               Homicidios dolosos en grado de tentativa               54
# 2                           Muertes en accidentes viales              121
# 3                   Homicidios culposos por otros hechos               35
# 4                                       Lesiones dolosas            13154
# ...                                                  ...              ...
# 21339  Contrabando de elementos nucleares agresivos q...                0
# 21340  Otros delitos previstos en leyes especiales n,c,p             3082
# 21341                                    Contravenciones              557
# 21342                             Suicidios (consumados)               22
# 21343     Delitos contra el orden económico y financiero                2
#
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 0                  158.0                   121.0                   37.0
# 1                   58.0                    40.0                   18.0
# 2                  126.0                    97.0                   29.0
# 3                   36.0                    20.0                   13.0
# 4                13732.0                  8105.0                 5485.0
# ...                  ...                     ...                    ...
# 21339                NaN                     NaN                    NaN
# 21340                NaN                     NaN                    NaN
# 21341                NaN                     NaN                    NaN
# 21342               22.0                    12.0                   10.0
# 21343                NaN                     NaN                    NaN
#
#        cantidad_victimas_sd tasa_hechos tasa_victimas tasa_victimas_masc  \
# 0                       0.0   4,9750013     5,2755051          8,8257008
# 1                       0.0   1,8030207     1,9365778          2,9175868
# 2                       0.0    4,040102     4,2070484          7,0751481
# 3                       3.0   1,1686245     1,2020137          1,4587934
# 4                     142.0   439,20248     458,50146          591,17603
# ...                     ...         ...           ...                ...
# 21339                   NaN           0           NaN                NaN
# 21340                   NaN   1693,5648           NaN                NaN
# 21341                   NaN   306,07254           NaN                NaN
# 21342                   0.0   13,150816     13,150816          14,091123
# 21343                   NaN   1,0990038           NaN                NaN
#
#       tasa_victimas_fem
# 0             2,2783601
# 1             1,1083914
# 2             1,7857418
# 3             ,80050492
# 4              337,7515
# ...                 ...
# 21339               NaN
# 21340               NaN
# 21341               NaN
# 21342         12,175818
# 21343               NaN
#
# [21344 rows x 13 columns]

# %% [markdown]
# The amount of `victims` shoul be an `int` and the `tasa` related columns a float. But this one, as in Spanish we use the "," insted of "." for decimals, is read as an string

# %%
problematic_cols = ["tasa_hechos", "tasa_victimas", "tasa_victimas_masc", "tasa_victimas_fem"]

# %%
for col in problematic_cols:
  crimes[col] =  crimes[col].str.replace("," , ".")

# %%
crimes[problematic_cols] = crimes[problematic_cols].astype(float)

# %% [markdown]
# Now we have to change to `int` the nominal amount of victims

# %%
crimes[["cantidad_victimas", "cantidad_victimas_masc", "cantidad_victimas_fem",	"cantidad_victimas_sd"]] = crimes[["cantidad_victimas", "cantidad_victimas_masc", "cantidad_victimas_fem",	"cantidad_victimas_sd"]].round(0).astype('Int64')

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21344 entries, 0 to 21343
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_provincia_indec      21344 non-null  int64
#  1   anio                    21344 non-null  int64
#  2   id_snic                 21344 non-null  object
#  3   nombre_snic             21344 non-null  object
#  4   cantidad_hechos         21344 non-null  int64
#  5   cantidad_victimas       7608 non-null   Int64
#  6   cantidad_victimas_masc  7608 non-null   Int64
#  7   cantidad_victimas_fem   7608 non-null   Int64
#  8   cantidad_victimas_sd    7608 non-null   Int64
#  9   tasa_hechos             21344 non-null  float64
#  10  tasa_victimas           7608 non-null   float64
#  11  tasa_victimas_masc      7608 non-null   float64
#  12  tasa_victimas_fem       7608 non-null   float64
# dtypes: Int64(4), float64(4), int64(3), object(2)
# memory usage: 2.2+ MB

# %%
del missing_val_crimes, non_missing_val_crimes, missing_val_crimes_sum, non_missing_val_crimes_sum, problematic_cols

# %% [markdown]
# ### Suicides

# %%
suicides
# Out:
#        id_hecho  id_departamento_indec       fecha      hora  \
# 2          8569                  78021  01-01-2017  19:00:00
# 3          8705                  58035  31-01-2017  17:30:00
# 4          8706                  58035  31-01-2017  22:40:00
# 5          8707                  58035  29-01-2017  20:30:00
# 6          8708                  58049  02-01-2017  14:25:00
# ...         ...                    ...         ...       ...
# 21713     38831                  14021  28-08-2022  11:11:11
# 21714     37640                  18049  09-07-2022  07:30:00
# 21715     37642                  18070  11-09-2022  05:00:00
# 21716     37643                  18070  27-09-2022  06:45:00
# 21717     37639                  18133  15-07-2022  08:45:00
#
#                             lugar       modalidad        origen_registro  \
# 2                     Vía pública    Ahorcamiento    Denuncia particular
# 3      Otro Lugar ( Especificar )   Arma de fuego  Intervención policial
# 4            Domicilio particular    Ahorcamiento  Intervención policial
# 5            Domicilio particular    Ahorcamiento  Intervención policial
# 6            Domicilio particular    Ahorcamiento  Intervención policial
# ...                           ...             ...                    ...
# 21713        Domicilio particular    Ahorcamiento  Intervención policial
# 21714          Cárcel o comisaría    Ahorcamiento  Intervención policial
# 21715        Domicilio particular  Sin determinar  Intervención policial
# 21716        Domicilio particular    Ahorcamiento  Intervención policial
# 21717  Otro Lugar ( Especificar )    Ahorcamiento  Intervención policial
#
#       suicida_sexo suicida_rango_edad suicida_identidad_genero
# 2        Masculino              15-19           Sin determinar
# 3        Masculino              20-24           Sin determinar
# 4        Masculino              20-24           Sin determinar
# 5        Masculino              20-24           Sin determinar
# 6        Masculino              45-49           Sin determinar
# ...            ...                ...                      ...
# 21713     Femenino              15-19                    Mujer
# 21714    Masculino              30-34                    Varón
# 21715    Masculino              50-54                    Varón
# 21716    Masculino              15-19                    Varón
# 21717    Masculino              30-34                    Varón
#
# [21426 rows x 10 columns]

# %%
suicides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21426 entries, 2 to 21717
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_hecho                  21426 non-null  int64
#  1   id_departamento_indec     21426 non-null  int64
#  2   fecha                     21426 non-null  object
#  3   hora                      21426 non-null  object
#  4   lugar                     21426 non-null  object
#  5   modalidad                 21426 non-null  object
#  6   origen_registro           21426 non-null  object
#  7   suicida_sexo              21426 non-null  object
#  8   suicida_rango_edad        21426 non-null  object
#  9   suicida_identidad_genero  21426 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.8+ MB

# %% [markdown]
# We don´t have any `Null` value. The datatypes look correct.
#
# However, it would be useful to see the values for our categorical variables. It seems like `suicida_identidad_genero` has "Sin Determinar" vals.

# %%
categorical_cols = ["fecha", "hora",	"lugar", 	"modalidad", "origen_registro", "suicida_sexo",	"suicida_rango_edad", "suicida_identidad_genero"]

# %%
for col in categorical_cols:
  print(suicides[col].value_counts())
  print("------------------------------")
# Out:
# 01-01-2021    27
# 01-01-2019    25
# 13-12-2021    24
# 20-01-2019    22
# 16-10-2022    22
#               ..
# 31-05-2019     2
# 20-12-2017     2
# 26-07-2019     1
# 20-02-2017     1
# 08-06-2020     1
# Name: fecha, Length: 2191, dtype: int64
# ------------------------------
# 00:00:00    506
# 12:00:00    337
# 11:00:00    315
# 18:00:00    309
# 11:11:11    304
#            ...
# 00:44:00      1
# 21:41:00      1
# 17:36:00      1
# 05:42:00      1
# 04:46:00      1
# Name: hora, Length: 1528, dtype: int64
# ------------------------------
# Domicilio particular          16137
# Vía pública                    2294
# Sin determinar                 1261
# Otro Lugar ( Especificar )     1230
# Vías del FF.CC.                 276
# Cárcel o comisaría              228
# Name: lugar, dtype: int64
# ------------------------------
# Ahorcamiento                        14472
# Arma de fuego                        3381
# Sin determinar                       1380
# Se arroja al vacío                    747
# Envenenamiento                        568
# Se arroja a las vías de FF.CC.        275
# Arma blanca /  elemento cortante      254
# Sumersión en piscina / mar / río      163
# Se incinera                           132
# Otra modalidad                         54
# Name: modalidad, dtype: int64
# ------------------------------
# Intervención policial    15114
# Denuncia particular       5968
# Sin determinar             181
# Orden judicial             149
# Otros                       14
# Name: origen_registro, dtype: int64
# ------------------------------
# Masculino         16901
# Femenino           4421
# Sin determinar      104
# Name: suicida_sexo, dtype: int64
# ------------------------------
# 20-24             2935
# 25-29             2553
# 15-19             2317
# 30-34             1976
# 35-39             1630
# 40-44             1458
# 45-49             1184
# 50-54             1105
# 55-59             1022
# 60-64              977
# Sin determinar     886
# 65-69              831
# 70-74              733
# 75-79              592
# 80-84              452
# 10-14              370
# 85-89              258
# 90 y más           134
# 5-9                 13
# Name: suicida_rango_edad, dtype: int64
# ------------------------------
# Sin determinar          14726
# Varón                    5206
# Mujer                    1489
# Mujer trans/travesti        4
# Varón trans                 1
# Name: suicida_identidad_genero, dtype: int64
# ------------------------------

# %% [markdown]
# Only in the `suicida_identidad_genero` the majority of rows have the "Sin determinar" value.
#
# The [User Manual](https://minsegar-my.sharepoint.com/personal/dnec_minseg_gob_ar/Documents/Argentina.gob.ar/Bases/Bases%20SAT/Bases%20SAT%20SS/Manual%20de%20usuario%20de%20la%20base%20SAT%20SS/Manual_de_usuario_Base_SAT-SS_2022.pdf?ga=1) (page 29) says in relation to this:
#
# "
# De acuerdo a la Ley de Identidad de Género Nro. 26.743, se entiende por identidad de
# género: “la vivencia interna e individual del género tal como cada persona la siente, la
# cual puede corresponder o no con el sexo asignado a momento del nacimiento,
# incluyendo la vivencia personal del cuerpo. Esto puede involucrar la modificación de la
# apariencia o la función corporal a través de medios farmacológicos, quirúrgicos o de otra
# índole, siempre que ello sea libremente”
#
# [...]
#
# 99.Sin determinar
# Se utiliza cuando no se dispone de información suficiente para determinar la
# identidad de género de la persona.
#
# "
#
# Based on the fact that this column is related to a personal experience of the suicidial, it makes sense that most of the data will be missing.
#
# Anyways, we will keep all the rows, since the "Sin determinar" value is not predominant for the other columns.

# %% [markdown]
# ### Mean Income

# %%
mean_income
# Out:
#               fecha  id_departamento_indec  clae2  w_mean
# 0        2014-01-01                   2000      1   13085
# 1        2014-01-01                   2000      2   10081
# 2        2014-01-01                   2000      3   17837
# 3        2014-01-01                   2000      5   57688
# 4        2014-01-01                   2000      6   62211
# ...             ...                    ...    ...     ...
# 3597392  2023-09-01                  94014     93  536119
# 3597393  2023-09-01                  94014     94  504914
# 3597394  2023-09-01                  94014     95  367788
# 3597395  2023-09-01                  94014     96  316829
# 3597396  2023-09-01                  94014    999  711491
#
# [3587653 rows x 4 columns]

# %%
mean_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3587653 entries, 0 to 3597396
# Data columns (total 4 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   fecha                  object
#  1   id_departamento_indec  int64
#  2   clae2                  int64
#  3   w_mean                 int64
# dtypes: int64(3), object(1)
# memory usage: 136.9+ MB

# %% [markdown]
# Nothing to do here. The datatypes are correct. We just have to be careful with the dates, consider the specific format that this dataset uses `yyyy-mm-dd`

# %% [markdown]
# ### CLAE2

# %%
clae2
# Out:
#     clae2                                         clae2_desc
# 0       1  Agricultura, ganadería, caza y servicios relac...
# 1       2                Silvicultura y explotación forestal
# 2       3                                Pesca y acuicultura
# 3       5                     Extracción de carbón y lignito
# 4       6         Extracción de petróleo crudo y gas natural
# ..    ...                                                ...
# 81     93  Actividades deportivas, recreativas y de entre...
# 82     94                          Servicios de asociaciones
# 83     95  Reparación de computadoras y equipos de uso do...
# 84     96                         Otros servicios personales
# 85    999                                     Otros sectores
#
# [86 rows x 2 columns]

# %%
clae2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 0 to 85
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   clae2       86 non-null     int64
#  1   clae2_desc  86 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# ## Saving the datasets

# %%
clean_data_dir = current_directory + "Clean_Data/"

# %%
provinces.to_csv(clean_data_dir+"provincias.csv", index=False)

# %%
departments.to_csv(clean_data_dir+"departamentos.csv", index=False)

# %%
crimes.to_csv(clean_data_dir+"crimenes.csv", index=False)

# %%
suicides.to_csv(clean_data_dir+"suicidios.csv", index=False)

# %%
mean_income.to_csv(clean_data_dir+"ingresos_promedio.csv", )

# %%
clae2.to_csv(clean_data_dir+"clae2.csv")

# %%
del clean_data_dir, province
